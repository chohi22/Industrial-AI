# %% [markdown]
# ## FP-Growth Algorithm

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder 
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth

# %%
dataset = [['mbalvi', '5 kilo meters', 'remember to Walk'], ['mbalvi', 'remember to Walk'],
['Divergent', 'Hassan','remember to Walk'], ['mbalvi', 'Five kilo meters'],
['Divergent','Hassan']] 
te = TransactionEncoder()
te_array = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_array, columns=te.columns_)

# %%
df
# Out:
#    5 kilo meters  Divergent  Five kilo meters  Hassan  mbalvi  \
# 0           True      False             False   False    True
# 1          False      False             False   False    True
# 2          False       True             False    True   False
# 3          False      False              True   False    True
# 4          False       True             False    True   False
#
#    remember to Walk
# 0              True
# 1              True
# 2              True
# 3             False
# 4             False

# %%
dataset
# Out:
# [['mbalvi', '5 kilo meters', 'remember to Walk'],
#  ['mbalvi', 'remember to Walk'],
#  ['Divergent', 'Hassan', 'remember to Walk'],
#  ['mbalvi', 'Five kilo meters'],
#  ['Divergent', 'Hassan']]

# %%
frequent_itemsets_fp=fpgrowth(df, min_support=0.02, use_colnames=True)

frequent_itemsets_fp=fpgrowth(df, min_support=0.02, use_colnames=True)

# %%
#rules_fp = association_rules(frequent_itemsets_fp, metric="confidence", min_threshold=0.8)

rules_fp = association_rules(frequent_itemsets_fp, frequent_itemsets_fp['support'].sum(), metric="confidence", min_threshold=0.8)
rules_fp
# Out:
#                          antecedents                 consequents  \
# 0                    (5 kilo meters)                    (mbalvi)
# 1                    (5 kilo meters)          (remember to Walk)
# 2            (5 kilo meters, mbalvi)          (remember to Walk)
# 3  (5 kilo meters, remember to Walk)                    (mbalvi)
# 4                    (5 kilo meters)  (mbalvi, remember to Walk)
# 5                           (Hassan)                 (Divergent)
# 6                        (Divergent)                    (Hassan)
# 7         (Hassan, remember to Walk)                 (Divergent)
# 8      (Divergent, remember to Walk)                    (Hassan)
# 9                 (Five kilo meters)                    (mbalvi)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0                 0.2                 0.6      0.2         1.0  1.666667
# 1                 0.2                 0.6      0.2         1.0  1.666667
# 2                 0.2                 0.6      0.2         1.0  1.666667
# 3                 0.2                 0.6      0.2         1.0  1.666667
# 4                 0.2                 0.4      0.2         1.0  2.500000
# 5                 0.4                 0.4      0.4         1.0  2.500000
# 6                 0.4                 0.4      0.4         1.0  2.500000
# 7                 0.2                 0.4      0.2         1.0  2.500000
# 8                 0.2                 0.4      0.2         1.0  2.500000
# 9                 0.2                 0.6      0.2         1.0  1.666667
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0      0.08         inf           0.50  0.333333        1.0
# 1               1.0      0.08         inf           0.50  0.333333        1.0
# 2               1.0      0.08         inf           0.50  0.333333        1.0
# 3               1.0      0.08         inf           0.50  0.333333        1.0
# 4               1.0      0.12         inf           0.75  0.500000        1.0
# 5               1.0      0.24         inf           1.00  1.000000        1.0
# 6               1.0      0.24         inf           1.00  1.000000        1.0
# 7               1.0      0.12         inf           0.75  0.500000        1.0
# 8               1.0      0.12         inf           0.75  0.500000        1.0
# 9               1.0      0.08         inf           0.50  0.333333        1.0
#
#    kulczynski
# 0    0.666667
# 1    0.666667
# 2    0.666667
# 3    0.666667
# 4    0.750000
# 5    1.000000
# 6    1.000000
# 7    0.750000
# 8    0.750000
# 9    0.666667

# %%
frequent_itemsets_fp
# Out:
#     support                                   itemsets
# 0       0.6                         (remember to Walk)
# 1       0.6                                   (mbalvi)
# 2       0.2                            (5 kilo meters)
# 3       0.4                                   (Hassan)
# 4       0.4                                (Divergent)
# 5       0.2                         (Five kilo meters)
# 6       0.4                 (mbalvi, remember to Walk)
# 7       0.2                    (5 kilo meters, mbalvi)
# 8       0.2          (5 kilo meters, remember to Walk)
# 9       0.2  (5 kilo meters, mbalvi, remember to Walk)
# 10      0.2                 (Hassan, remember to Walk)
# 11      0.4                        (Hassan, Divergent)
# 12      0.2              (Divergent, remember to Walk)
# 13      0.2      (Hassan, Divergent, remember to Walk)
# 14      0.2                 (Five kilo meters, mbalvi)
