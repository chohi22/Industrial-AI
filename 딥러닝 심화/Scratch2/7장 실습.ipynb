# %% [markdown]
# ### RNN을 사용한 문장 생성

# %%
import sys
sys.path.append('..')
import numpy as np
from common.functions import softmax
from rnnlm import Rnnlm
from better_rnnlm import BetterRnnlm

class RnnlnGen(Rnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x)
            p = softmax(score.flatten())

            sampled = np.random.choice(len(p), size=1, p=p)
            if(skip_ids is None or sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))

        return word_ids

# %%
import sys
sys.path.append('..')
from rnnlm_gen import RnnlmGen
from dataset import ptb

corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)

model = RnnlmGen()

start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]

word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print(txt)
# Out:
# you potentially military chairs vacated st. zenith deterioration rampant bumiputra speech favor devastation mattel helpful roderick trade armed afloat count trelleborg columbia comparable pressing actress unidentified win inhibit baltimore reaction rewrite armed alleged acquirer indexing processed highlight wholly head disk-drive detect ongoing capita neuberger announcer consolidate horse associates concentrated overruns factor pointing readers russell thomson set portions earns historical bacteria theatre runaway lbos frightened whatever lined upper biggest far-reaching reported reproductive governors civilian expenses subscribe education haunts tele-communications casinos brain canton syndicates handful dismal firms editorial-page storage dialing broadcast evening list malcolm francisco applies aware guterman characterized basket emerson supervisor

# %%
model.reset_state()

start_words = 'the meaning of life is'
start_ids = [word_to_id[w] for w in start_words.split(' ')]

for x in start_ids[:-1]:
    x = np.array(x).reshape(1, 1)
    model.predict(x)

word_ids = model.generate(start_ids[-1], skip_ids)
word_ids = start_ids[:-1] + word_ids
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print('-' * 50)
print(txt)
# Out:
# --------------------------------------------------
# the meaning of life is conference receive moody environmentalists excitement col. jamaica dairy hammond pot ceiling parking rarely challenging custody honduras pump spain deeply king minpeco landmark park drafted runaway shell scott opened neighbors figuring highlight midday noticed insist hot smooth radio laurel sperry merchant department-store figures ariz. el abrams petition porter focuses distributing protein sansui labeled corporations full-time rejected non-interest allow depletion lived unique entering talks wants only prosecuted banned hailed clears inflation-adjusted injunction bullet retailers deserves bart on amazing approached spree medium cooperate fans diminished profitable scripts referred lion cbs defendants winners woman climbed adjustments jokes art provision psychiatric islands exemption 300-a-share

# %% [markdown]
# ### seq2seq

# %%
import sys
sys.path.append('..')
from dataset import sequence


(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt', seed=1984)
char_to_id, id_to_char = sequence.get_vocab()

print(x_train.shape, t_train.shape)
print(x_test.shape, t_test.shape)
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)

print(x_train[0])
print(t_train[0])
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]

print(''.join([id_to_char[c] for c in x_train[0]]))
print(''.join([id_to_char[c] for c in t_train[0]]))
# 71+118
# _189
# Out:
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]
# 71+118
# _189

# %%
class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=False)

        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None

    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]

    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %%
class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, h):
        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score

    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        sample_id = start_id
        self.lstm.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1, 1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)

            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))

        return sampled

# %%
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel

class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]

        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss

    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout

    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
# from seq2seq import Seq2seq
# from peeky_seq2seq import PeekySeq2seq


# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 반전 여부 설정 =============================================
is_reverse = False  # True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 일반 혹은 엿보기(Peeky) 설정 =====================================
model = Seq2seq(vocab_size, wordvec_size, hidden_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))

# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.53
# | 에폭 1 |  반복 41 / 351 | 시간 0[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.92
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.87
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.85
# | 에폭 1 |  반복 141 / 351 | 시간 2[s] | 손실 1.83
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 3[s] | 손실 1.77
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 281 / 351 | 시간 6[s] | 손실 1.75
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 7[s] | 손실 1.75
# | 에폭 1 |  반복 341 / 351 | 시간 8[s] | 손실 1.74
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 1000
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 1000
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1000
# ---
# Q 26+838
# T 864
# ☒ 1000
# ---
# Q 143+93
# T 236
# ☒ 100
# ---
# 검증 정확도 0.180%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.74
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.73
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.74
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.74
# | 에폭 2 |  반복 81 / 351 | 시간 2[s] | 손실 1.73
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.73
# | 에폭 2 |  반복 121 / 351 | 시간 3[s] | 손실 1.72
# | 에폭 2 |  반복 141 / 351 | 시간 4[s] | 손실 1.71
# | 에폭 2 |  반복 161 / 351 | 시간 4[s] | 손실 1.71
# | 에폭 2 |  반복 181 / 351 | 시간 4[s] | 손실 1.71
# | 에폭 2 |  반복 201 / 351 | 시간 5[s] | 손실 1.70
# | 에폭 2 |  반복 221 / 351 | 시간 5[s] | 손실 1.71
# | 에폭 2 |  반복 241 / 351 | 시간 6[s] | 손실 1.70
# | 에폭 2 |  반복 261 / 351 | 시간 6[s] | 손실 1.69
# | 에폭 2 |  반복 281 / 351 | 시간 7[s] | 손실 1.69
# | 에폭 2 |  반복 301 / 351 | 시간 7[s] | 손실 1.69
# | 에폭 2 |  반복 321 / 351 | 시간 8[s] | 손실 1.68
# | 에폭 2 |  반복 341 / 351 | 시간 9[s] | 손실 1.67
# Q 77+85
# T 162
# ☒ 994
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 700
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 400
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1544
# ---
# Q 26+838
# T 864
# ☒ 400
# ---
# Q 143+93
# T 236
# ☒ 400
# ---
# 검증 정확도 0.220%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.66
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.66
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.65
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.63
# | 에폭 3 |  반복 81 / 351 | 시간 2[s] | 손실 1.62
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.62
# | 에폭 3 |  반복 121 / 351 | 시간 3[s] | 손실 1.60
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.59
# | 에폭 3 |  반복 161 / 351 | 시간 4[s] | 손실 1.57
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.57
# | 에폭 3 |  반복 201 / 351 | 시간 4[s] | 손실 1.56
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.54
# | 에폭 3 |  반복 241 / 351 | 시간 6[s] | 손실 1.52
# | 에폭 3 |  반복 261 / 351 | 시간 6[s] | 손실 1.52
# | 에폭 3 |  반복 281 / 351 | 시간 6[s] | 손실 1.52
# | 에폭 3 |  반복 301 / 351 | 시간 7[s] | 손실 1.50
# | 에폭 3 |  반복 321 / 351 | 시간 7[s] | 손실 1.49
# | 에폭 3 |  반복 341 / 351 | 시간 8[s] | 손실 1.48
# Q 77+85
# T 162
# ☒ 108
# ---
# Q 975+164
# T 1139
# ☒ 1001
# ---
# Q 582+84
# T 666
# ☒ 648
# ---
# Q 8+155
# T 163
# ☒ 138
# ---
# Q 367+55
# T 422
# ☒ 448
# ---
# Q 600+257
# T 857
# ☒ 848
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1373
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 348
# ---
# 검증 정확도 0.560%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.47
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.46
# | 에폭 4 |  반복 41 / 351 | 시간 0[s] | 손실 1.44
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.43
# | 에폭 4 |  반복 81 / 351 | 시간 1[s] | 손실 1.42
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.41
# | 에폭 4 |  반복 121 / 351 | 시간 2[s] | 손실 1.40
# | 에폭 4 |  반복 141 / 351 | 시간 2[s] | 손실 1.40
# | 에폭 4 |  반복 161 / 351 | 시간 3[s] | 손실 1.38
# | 에폭 4 |  반복 181 / 351 | 시간 3[s] | 손실 1.38
# | 에폭 4 |  반복 201 / 351 | 시간 4[s] | 손실 1.37
# | 에폭 4 |  반복 221 / 351 | 시간 4[s] | 손실 1.35
# | 에폭 4 |  반복 241 / 351 | 시간 4[s] | 손실 1.33
# | 에폭 4 |  반복 261 / 351 | 시간 5[s] | 손실 1.33
# | 에폭 4 |  반복 281 / 351 | 시간 5[s] | 손실 1.33
# | 에폭 4 |  반복 301 / 351 | 시간 6[s] | 손실 1.32
# | 에폭 4 |  반복 321 / 351 | 시간 6[s] | 손실 1.31
# | 에폭 4 |  반복 341 / 351 | 시간 7[s] | 손실 1.30
# Q 77+85
# T 162
# ☒ 146
# ---
# Q 975+164
# T 1139
# ☒ 1189
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 432
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1002
# ---
# Q 830+597
# T 1427
# ☒ 1406
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 202
# ---
# 검증 정확도 1.060%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.29
# | 에폭 5 |  반복 41 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 1.27
# | 에폭 5 |  반복 81 / 351 | 시간 1[s] | 손실 1.27
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 1.26
# | 에폭 5 |  반복 121 / 351 | 시간 2[s] | 손실 1.26
# | 에폭 5 |  반복 141 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 5 |  반복 161 / 351 | 시간 3[s] | 손실 1.26
# | 에폭 5 |  반복 181 / 351 | 시간 3[s] | 손실 1.25
# | 에폭 5 |  반복 201 / 351 | 시간 4[s] | 손실 1.23
# | 에폭 5 |  반복 221 / 351 | 시간 4[s] | 손실 1.22
# | 에폭 5 |  반복 241 / 351 | 시간 4[s] | 손실 1.21
# | 에폭 5 |  반복 261 / 351 | 시간 5[s] | 손실 1.21
# | 에폭 5 |  반복 281 / 351 | 시간 5[s] | 손실 1.21
# | 에폭 5 |  반복 301 / 351 | 시간 6[s] | 손실 1.20
# | 에폭 5 |  반복 321 / 351 | 시간 6[s] | 손실 1.19
# | 에폭 5 |  반복 341 / 351 | 시간 7[s] | 손실 1.18
# Q 77+85
# T 162
# ☒ 145
# ---
# Q 975+164
# T 1139
# ☒ 1168
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 192
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 895
# ---
# Q 761+292
# T 1053
# ☒ 1015
# ---
# Q 830+597
# T 1427
# ☒ 1493
# ---
# Q 26+838
# T 864
# ☒ 891
# ---
# Q 143+93
# T 236
# ☒ 221
# ---
# 검증 정확도 2.260%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 1.18
# | 에폭 6 |  반복 61 / 351 | 시간 2[s] | 손실 1.17
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 1.16
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 1.16
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 1.16
# | 에폭 6 |  반복 141 / 351 | 시간 4[s] | 손실 1.14
# | 에폭 6 |  반복 161 / 351 | 시간 4[s] | 손실 1.14
# | 에폭 6 |  반복 181 / 351 | 시간 4[s] | 손실 1.13
# | 에폭 6 |  반복 201 / 351 | 시간 5[s] | 손실 1.15
# | 에폭 6 |  반복 221 / 351 | 시간 5[s] | 손실 1.14
# | 에폭 6 |  반복 241 / 351 | 시간 6[s] | 손실 1.13
# | 에폭 6 |  반복 261 / 351 | 시간 6[s] | 손실 1.11
# | 에폭 6 |  반복 281 / 351 | 시간 7[s] | 손실 1.16
# | 에폭 6 |  반복 301 / 351 | 시간 7[s] | 손실 1.13
# | 에폭 6 |  반복 321 / 351 | 시간 8[s] | 손실 1.10
# | 에폭 6 |  반복 341 / 351 | 시간 8[s] | 손실 1.10
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1191
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 199
# ---
# Q 367+55
# T 422
# ☒ 440
# ---
# Q 600+257
# T 857
# ☒ 870
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1410
# ---
# Q 26+838
# T 864
# ☒ 856
# ---
# Q 143+93
# T 236
# ☒ 270
# ---
# 검증 정확도 2.800%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 1.12
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 1.11
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 1.09
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 1.10
# | 에폭 7 |  반복 81 / 351 | 시간 2[s] | 손실 1.09
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 1.09
# | 에폭 7 |  반복 121 / 351 | 시간 3[s] | 손실 1.09
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 1.07
# | 에폭 7 |  반복 161 / 351 | 시간 4[s] | 손실 1.08
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 1.07
# | 에폭 7 |  반복 201 / 351 | 시간 5[s] | 손실 1.07
# | 에폭 7 |  반복 221 / 351 | 시간 5[s] | 손실 1.06
# | 에폭 7 |  반복 241 / 351 | 시간 6[s] | 손실 1.06
# | 에폭 7 |  반복 261 / 351 | 시간 7[s] | 손실 1.08
# | 에폭 7 |  반복 281 / 351 | 시간 7[s] | 손실 1.07
# | 에폭 7 |  반복 301 / 351 | 시간 8[s] | 손실 1.06
# | 에폭 7 |  반복 321 / 351 | 시간 8[s] | 손실 1.05
# | 에폭 7 |  반복 341 / 351 | 시간 9[s] | 손실 1.04
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1166
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 161
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 892
# ---
# Q 761+292
# T 1053
# ☒ 1058
# ---
# Q 830+597
# T 1427
# ☒ 1444
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 228
# ---
# 검증 정확도 3.500%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 1.06
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 8 |  반복 41 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 1.04
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 1.03
# | 에폭 8 |  반복 101 / 351 | 시간 3[s] | 손실 1.05
# | 에폭 8 |  반복 121 / 351 | 시간 4[s] | 손실 1.04
# | 에폭 8 |  반복 141 / 351 | 시간 4[s] | 손실 1.04
# | 에폭 8 |  반복 161 / 351 | 시간 5[s] | 손실 1.03
# | 에폭 8 |  반복 181 / 351 | 시간 5[s] | 손실 1.02
# | 에폭 8 |  반복 201 / 351 | 시간 6[s] | 손실 1.03
# | 에폭 8 |  반복 221 / 351 | 시간 7[s] | 손실 1.01
# | 에폭 8 |  반복 241 / 351 | 시간 7[s] | 손실 1.01
# | 에폭 8 |  반복 261 / 351 | 시간 8[s] | 손실 1.01
# | 에폭 8 |  반복 281 / 351 | 시간 8[s] | 손실 1.02
# | 에폭 8 |  반복 301 / 351 | 시간 9[s] | 손실 1.01
# | 에폭 8 |  반복 321 / 351 | 시간 10[s] | 손실 1.01
# | 에폭 8 |  반복 341 / 351 | 시간 10[s] | 손실 1.00
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 853
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1449
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 5.200%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 1.03
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 1.01
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 1.00
# | 에폭 9 |  반복 101 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 1.03
# | 에폭 9 |  반복 141 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 1.01
# | 에폭 9 |  반복 181 / 351 | 시간 4[s] | 손실 0.97
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 0.98
# | 에폭 9 |  반복 221 / 351 | 시간 5[s] | 손실 0.98
# | 에폭 9 |  반복 241 / 351 | 시간 6[s] | 손실 1.00
# | 에폭 9 |  반복 261 / 351 | 시간 7[s] | 손실 0.99
# | 에폭 9 |  반복 281 / 351 | 시간 7[s] | 손실 0.98
# | 에폭 9 |  반복 301 / 351 | 시간 8[s] | 손실 0.98
# | 에폭 9 |  반복 321 / 351 | 시간 8[s] | 손실 0.99
# | 에폭 9 |  반복 341 / 351 | 시간 9[s] | 손실 0.97
# Q 77+85
# T 162
# ☒ 167
# ---
# Q 975+164
# T 1139
# ☒ 1128
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 857
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 5.100%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.95
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.97
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.96
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.98
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.96
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.98
# | 에폭 10 |  반복 121 / 351 | 시간 3[s] | 손실 0.97
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.97
# | 에폭 10 |  반복 161 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 0.97
# | 에폭 10 |  반복 221 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 10 |  반복 241 / 351 | 시간 6[s] | 손실 0.98
# | 에폭 10 |  반복 261 / 351 | 시간 6[s] | 손실 0.97
# | 에폭 10 |  반복 281 / 351 | 시간 7[s] | 손실 0.96
# | 에폭 10 |  반복 301 / 351 | 시간 8[s] | 손실 0.96
# | 에폭 10 |  반복 321 / 351 | 시간 8[s] | 손실 0.96
# | 에폭 10 |  반복 341 / 351 | 시간 9[s] | 손실 0.94
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1166
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 173
# ---
# Q 367+55
# T 422
# ☒ 430
# ---
# Q 600+257
# T 857
# ☒ 890
# ---
# Q 761+292
# T 1053
# ☒ 1075
# ---
# Q 830+597
# T 1427
# ☒ 1460
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 247
# ---
# 검증 정확도 3.980%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 11 |  반복 21 / 351 | 시간 1[s] | 손실 0.98
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.96
# | 에폭 11 |  반복 61 / 351 | 시간 2[s] | 손실 0.94
# | 에폭 11 |  반복 81 / 351 | 시간 3[s] | 손실 0.98
# | 에폭 11 |  반복 101 / 351 | 시간 3[s] | 손실 0.98
# | 에폭 11 |  반복 121 / 351 | 시간 4[s] | 손실 0.95
# | 에폭 11 |  반복 141 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 11 |  반복 161 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 11 |  반복 181 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 11 |  반복 201 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 11 |  반복 221 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 11 |  반복 241 / 351 | 시간 7[s] | 손실 1.00
# | 에폭 11 |  반복 261 / 351 | 시간 7[s] | 손실 0.94
# | 에폭 11 |  반복 281 / 351 | 시간 8[s] | 손실 0.93
# | 에폭 11 |  반복 301 / 351 | 시간 9[s] | 손실 0.93
# | 에폭 11 |  반복 321 / 351 | 시간 9[s] | 손실 0.93
# | 에폭 11 |  반복 341 / 351 | 시간 10[s] | 손실 0.93
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1161
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 172
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 848
# ---
# Q 761+292
# T 1053
# ☒ 1073
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 5.520%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.97
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.91
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.96
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 12 |  반복 141 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 12 |  반복 161 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 12 |  반복 181 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 12 |  반복 201 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 12 |  반복 221 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 12 |  반복 241 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 12 |  반복 261 / 351 | 시간 6[s] | 손실 0.90
# | 에폭 12 |  반복 281 / 351 | 시간 7[s] | 손실 0.95
# | 에폭 12 |  반복 301 / 351 | 시간 8[s] | 손실 0.91
# | 에폭 12 |  반복 321 / 351 | 시간 8[s] | 손실 0.90
# | 에폭 12 |  반복 341 / 351 | 시간 9[s] | 손실 0.91
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 681
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 861
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 5.860%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.91
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 13 |  반복 101 / 351 | 시간 2[s] | 손실 0.93
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 13 |  반복 141 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 13 |  반복 161 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 13 |  반복 181 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 13 |  반복 201 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 13 |  반복 221 / 351 | 시간 6[s] | 손실 0.93
# | 에폭 13 |  반복 241 / 351 | 시간 7[s] | 손실 0.92
# | 에폭 13 |  반복 261 / 351 | 시간 7[s] | 손실 0.92
# | 에폭 13 |  반복 281 / 351 | 시간 8[s] | 손실 0.92
# | 에폭 13 |  반복 301 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 13 |  반복 321 / 351 | 시간 9[s] | 손실 0.89
# | 에폭 13 |  반복 341 / 351 | 시간 9[s] | 손실 0.90
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1121
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# 검증 정확도 8.520%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 14 |  반복 101 / 351 | 시간 2[s] | 손실 0.91
# | 에폭 14 |  반복 121 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 14 |  반복 141 / 351 | 시간 3[s] | 손실 0.88
# | 에폭 14 |  반복 161 / 351 | 시간 4[s] | 손실 0.87
# | 에폭 14 |  반복 181 / 351 | 시간 5[s] | 손실 0.88
# | 에폭 14 |  반복 201 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 14 |  반복 221 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 14 |  반복 241 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 14 |  반복 261 / 351 | 시간 7[s] | 손실 0.91
# | 에폭 14 |  반복 281 / 351 | 시간 7[s] | 손실 0.90
# | 에폭 14 |  반복 301 / 351 | 시간 8[s] | 손실 0.90
# | 에폭 14 |  반복 321 / 351 | 시간 9[s] | 손실 0.90
# | 에폭 14 |  반복 341 / 351 | 시간 9[s] | 손실 0.88
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1128
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☒ 171
# ---
# Q 367+55
# T 422
# ☒ 411
# ---
# Q 600+257
# T 857
# ☒ 855
# ---
# Q 761+292
# T 1053
# ☒ 1070
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 6.920%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.87
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.87
# | 에폭 15 |  반복 121 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 15 |  반복 141 / 351 | 시간 4[s] | 손실 0.87
# | 에폭 15 |  반복 161 / 351 | 시간 4[s] | 손실 0.88
# | 에폭 15 |  반복 181 / 351 | 시간 5[s] | 손실 0.87
# | 에폭 15 |  반복 201 / 351 | 시간 6[s] | 손실 0.92
# | 에폭 15 |  반복 221 / 351 | 시간 7[s] | 손실 0.95
# | 에폭 15 |  반복 241 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 15 |  반복 261 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 15 |  반복 281 / 351 | 시간 8[s] | 손실 0.91
# | 에폭 15 |  반복 301 / 351 | 시간 9[s] | 손실 0.92
# | 에폭 15 |  반복 321 / 351 | 시간 10[s] | 손실 0.90
# | 에폭 15 |  반복 341 / 351 | 시간 10[s] | 손실 0.89
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1162
# ---
# Q 582+84
# T 666
# ☒ 676
# ---
# Q 8+155
# T 163
# ☒ 168
# ---
# Q 367+55
# T 422
# ☒ 428
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1063
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 3.820%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.89
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 16 |  반복 101 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 16 |  반복 121 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 16 |  반복 141 / 351 | 시간 4[s] | 손실 0.86
# | 에폭 16 |  반복 161 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 16 |  반복 181 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 16 |  반복 201 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 16 |  반복 221 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 16 |  반복 241 / 351 | 시간 7[s] | 손실 0.86
# | 에폭 16 |  반복 261 / 351 | 시간 7[s] | 손실 0.88
# | 에폭 16 |  반복 281 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 16 |  반복 301 / 351 | 시간 9[s] | 손실 0.88
# | 에폭 16 |  반복 321 / 351 | 시간 9[s] | 손실 0.88
# | 에폭 16 |  반복 341 / 351 | 시간 10[s] | 손실 0.87
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1127
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1072
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 852
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 6.640%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.87
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 17 |  반복 61 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.90
# | 에폭 17 |  반복 101 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 17 |  반복 121 / 351 | 시간 4[s] | 손실 0.87
# | 에폭 17 |  반복 141 / 351 | 시간 4[s] | 손실 0.87
# | 에폭 17 |  반복 161 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 17 |  반복 181 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 17 |  반복 201 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 17 |  반복 221 / 351 | 시간 7[s] | 손실 0.86
# | 에폭 17 |  반복 241 / 351 | 시간 8[s] | 손실 0.87
# | 에폭 17 |  반복 261 / 351 | 시간 8[s] | 손실 0.86
# | 에폭 17 |  반복 281 / 351 | 시간 9[s] | 손실 0.87
# | 에폭 17 |  반복 301 / 351 | 시간 9[s] | 손실 0.87
# | 에폭 17 |  반복 321 / 351 | 시간 10[s] | 손실 0.85
# | 에폭 17 |  반복 341 / 351 | 시간 10[s] | 손실 0.84
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1127
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 417
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1055
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 9.060%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.85
# | 에폭 18 |  반복 81 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 18 |  반복 101 / 351 | 시간 3[s] | 손실 0.83
# | 에폭 18 |  반복 121 / 351 | 시간 3[s] | 손실 0.85
# | 에폭 18 |  반복 141 / 351 | 시간 4[s] | 손실 0.84
# | 에폭 18 |  반복 161 / 351 | 시간 4[s] | 손실 0.85
# | 에폭 18 |  반복 181 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 18 |  반복 201 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 18 |  반복 221 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 18 |  반복 241 / 351 | 시간 7[s] | 손실 0.86
# | 에폭 18 |  반복 261 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 18 |  반복 281 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 18 |  반복 301 / 351 | 시간 9[s] | 손실 0.86
# | 에폭 18 |  반복 321 / 351 | 시간 9[s] | 손실 0.85
# | 에폭 18 |  반복 341 / 351 | 시간 10[s] | 손실 0.85
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1131
# ---
# Q 582+84
# T 666
# ☒ 659
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 10.260%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 19 |  반복 61 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 19 |  반복 81 / 351 | 시간 3[s] | 손실 0.86
# | 에폭 19 |  반복 101 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 19 |  반복 121 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 19 |  반복 141 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 19 |  반복 161 / 351 | 시간 6[s] | 손실 0.83
# | 에폭 19 |  반복 181 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 19 |  반복 201 / 351 | 시간 7[s] | 손실 0.83
# | 에폭 19 |  반복 221 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 19 |  반복 241 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 19 |  반복 261 / 351 | 시간 9[s] | 손실 0.83
# | 에폭 19 |  반복 281 / 351 | 시간 9[s] | 손실 0.82
# | 에폭 19 |  반복 301 / 351 | 시간 10[s] | 손실 0.87
# | 에폭 19 |  반복 321 / 351 | 시간 11[s] | 손실 0.81
# | 에폭 19 |  반복 341 / 351 | 시간 11[s] | 손실 0.83
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 171
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 8.400%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.81
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.86
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.85
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 20 |  반복 121 / 351 | 시간 3[s] | 손실 0.83
# | 에폭 20 |  반복 141 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 20 |  반복 161 / 351 | 시간 4[s] | 손실 0.84
# | 에폭 20 |  반복 181 / 351 | 시간 5[s] | 손실 0.88
# | 에폭 20 |  반복 201 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 20 |  반복 221 / 351 | 시간 6[s] | 손실 0.80
# | 에폭 20 |  반복 241 / 351 | 시간 6[s] | 손실 0.80
# | 에폭 20 |  반복 261 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 20 |  반복 281 / 351 | 시간 8[s] | 손실 0.80
# | 에폭 20 |  반복 301 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 20 |  반복 321 / 351 | 시간 9[s] | 손실 0.83
# | 에폭 20 |  반복 341 / 351 | 시간 9[s] | 손실 0.81
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 862
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 872
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# 검증 정확도 7.600%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 21 |  반복 81 / 351 | 시간 2[s] | 손실 0.85
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 21 |  반복 121 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 21 |  반복 141 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 21 |  반복 161 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 21 |  반복 181 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 21 |  반복 201 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 21 |  반복 221 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 21 |  반복 241 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 21 |  반복 261 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 21 |  반복 281 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 21 |  반복 301 / 351 | 시간 8[s] | 손실 0.80
# | 에폭 21 |  반복 321 / 351 | 시간 9[s] | 손실 0.83
# | 에폭 21 |  반복 341 / 351 | 시간 9[s] | 손실 0.81
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 870
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 6.860%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.79
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.80
# | 에폭 22 |  반복 81 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.78
# | 에폭 22 |  반복 121 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 22 |  반복 161 / 351 | 시간 4[s] | 손실 0.82
# | 에폭 22 |  반복 181 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 22 |  반복 201 / 351 | 시간 5[s] | 손실 0.79
# | 에폭 22 |  반복 221 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 22 |  반복 241 / 351 | 시간 6[s] | 손실 0.83
# | 에폭 22 |  반복 261 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 22 |  반복 281 / 351 | 시간 7[s] | 손실 0.81
# | 에폭 22 |  반복 301 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 22 |  반복 321 / 351 | 시간 8[s] | 손실 0.80
# | 에폭 22 |  반복 341 / 351 | 시간 9[s] | 손실 0.78
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1120
# ---
# Q 582+84
# T 666
# ☒ 670
# ---
# Q 8+155
# T 163
# ☒ 167
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# 검증 정확도 7.600%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.80
# | 에폭 23 |  반복 61 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 23 |  반복 81 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 23 |  반복 101 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 23 |  반복 121 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 23 |  반복 141 / 351 | 시간 4[s] | 손실 0.77
# | 에폭 23 |  반복 161 / 351 | 시간 4[s] | 손실 0.79
# | 에폭 23 |  반복 181 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 23 |  반복 201 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 23 |  반복 221 / 351 | 시간 6[s] | 손실 0.78
# | 에폭 23 |  반복 241 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 23 |  반복 261 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 23 |  반복 281 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 23 |  반복 301 / 351 | 시간 8[s] | 손실 0.78
# | 에폭 23 |  반복 321 / 351 | 시간 9[s] | 손실 0.79
# | 에폭 23 |  반복 341 / 351 | 시간 9[s] | 손실 0.81
# Q 77+85
# T 162
# ☒ 159
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 415
# ---
# Q 600+257
# T 857
# ☒ 850
# ---
# Q 761+292
# T 1053
# ☒ 1038
# ---
# Q 830+597
# T 1427
# ☒ 1390
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 6.760%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.83
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 24 |  반복 61 / 351 | 시간 2[s] | 손실 0.80
# | 에폭 24 |  반복 81 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 24 |  반복 101 / 351 | 시간 3[s] | 손실 0.77
# | 에폭 24 |  반복 121 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 24 |  반복 141 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 24 |  반복 161 / 351 | 시간 6[s] | 손실 0.78
# | 에폭 24 |  반복 181 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 24 |  반복 201 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 24 |  반복 221 / 351 | 시간 8[s] | 손실 0.78
# | 에폭 24 |  반복 241 / 351 | 시간 9[s] | 손실 0.78
# | 에폭 24 |  반복 261 / 351 | 시간 10[s] | 손실 0.79
# | 에폭 24 |  반복 281 / 351 | 시간 11[s] | 손실 0.78
# | 에폭 24 |  반복 301 / 351 | 시간 11[s] | 손실 0.82
# | 에폭 24 |  반복 321 / 351 | 시간 12[s] | 손실 0.78
# | 에폭 24 |  반복 341 / 351 | 시간 13[s] | 손실 0.78
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 415
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 8.620%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.77
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 0.76
# | 에폭 25 |  반복 61 / 351 | 시간 2[s] | 손실 0.75
# | 에폭 25 |  반복 81 / 351 | 시간 2[s] | 손실 0.75
# | 에폭 25 |  반복 101 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 25 |  반복 121 / 351 | 시간 4[s] | 손실 0.75
# | 에폭 25 |  반복 141 / 351 | 시간 5[s] | 손실 0.76
# | 에폭 25 |  반복 161 / 351 | 시간 6[s] | 손실 0.75
# | 에폭 25 |  반복 181 / 351 | 시간 7[s] | 손실 0.76
# | 에폭 25 |  반복 201 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 25 |  반복 221 / 351 | 시간 9[s] | 손실 0.79
# | 에폭 25 |  반복 241 / 351 | 시간 9[s] | 손실 0.79
# | 에폭 25 |  반복 261 / 351 | 시간 10[s] | 손실 0.78
# | 에폭 25 |  반복 281 / 351 | 시간 11[s] | 손실 0.78
# | 에폭 25 |  반복 301 / 351 | 시간 12[s] | 손실 0.79
# | 에폭 25 |  반복 321 / 351 | 시간 12[s] | 손실 0.78
# | 에폭 25 |  반복 341 / 351 | 시간 13[s] | 손실 0.79
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 671
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 426
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 246
# ---
# 검증 정확도 8.360%
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### seq2seq 개선

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq


# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 반전 여부 설정 =============================================
is_reverse = True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 일반 혹은 엿보기(Peeky) 설정 =====================================
model = Seq2seq(vocab_size, wordvec_size, hidden_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))

# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.52
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.91
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.87
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.86
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.84
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.80
# | 에폭 1 |  반복 181 / 351 | 시간 4[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 1.73
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 1001
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 1001
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1000
# ---
# Q 26+838
# T 864
# ☒ 1001
# ---
# Q 143+93
# T 236
# ☒ 703
# ---
# 검증 정확도 0.120%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.73
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.72
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.72
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.72
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.70
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.70
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.69
# | 에폭 2 |  반복 141 / 351 | 시간 2[s] | 손실 1.68
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.67
# | 에폭 2 |  반복 181 / 351 | 시간 3[s] | 손실 1.66
# | 에폭 2 |  반복 201 / 351 | 시간 3[s] | 손실 1.66
# | 에폭 2 |  반복 221 / 351 | 시간 4[s] | 손실 1.65
# | 에폭 2 |  반복 241 / 351 | 시간 4[s] | 손실 1.63
# | 에폭 2 |  반복 261 / 351 | 시간 5[s] | 손실 1.62
# | 에폭 2 |  반복 281 / 351 | 시간 5[s] | 손실 1.61
# | 에폭 2 |  반복 301 / 351 | 시간 6[s] | 손실 1.60
# | 에폭 2 |  반복 321 / 351 | 시간 6[s] | 손실 1.58
# | 에폭 2 |  반복 341 / 351 | 시간 7[s] | 손실 1.56
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 690
# ---
# Q 8+155
# T 163
# ☒ 1000
# ---
# Q 367+55
# T 422
# ☒ 470
# ---
# Q 600+257
# T 857
# ☒ 700
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1444
# ---
# Q 26+838
# T 864
# ☒ 700
# ---
# Q 143+93
# T 236
# ☒ 370
# ---
# 검증 정확도 0.400%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.52
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.53
# | 에폭 3 |  반복 41 / 351 | 시간 0[s] | 손실 1.51
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.49
# | 에폭 3 |  반복 81 / 351 | 시간 2[s] | 손실 1.47
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.45
# | 에폭 3 |  반복 121 / 351 | 시간 2[s] | 손실 1.44
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.42
# | 에폭 3 |  반복 161 / 351 | 시간 3[s] | 손실 1.40
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.38
# | 에폭 3 |  반복 201 / 351 | 시간 5[s] | 손실 1.37
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.35
# | 에폭 3 |  반복 241 / 351 | 시간 5[s] | 손실 1.33
# | 에폭 3 |  반복 261 / 351 | 시간 6[s] | 손실 1.32
# | 에폭 3 |  반복 281 / 351 | 시간 7[s] | 손실 1.30
# | 에폭 3 |  반복 301 / 351 | 시간 7[s] | 손실 1.29
# | 에폭 3 |  반복 321 / 351 | 시간 8[s] | 손실 1.28
# | 에폭 3 |  반복 341 / 351 | 시간 8[s] | 손실 1.27
# Q 77+85
# T 162
# ☒ 158
# ---
# Q 975+164
# T 1139
# ☒ 1148
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 382
# ---
# Q 600+257
# T 857
# ☒ 818
# ---
# Q 761+292
# T 1053
# ☒ 1008
# ---
# Q 830+597
# T 1427
# ☒ 1434
# ---
# Q 26+838
# T 864
# ☒ 838
# ---
# Q 143+93
# T 236
# ☒ 202
# ---
# 검증 정확도 1.940%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.26
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.25
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.23
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.22
# | 에폭 4 |  반복 81 / 351 | 시간 2[s] | 손실 1.20
# | 에폭 4 |  반복 101 / 351 | 시간 3[s] | 손실 1.19
# | 에폭 4 |  반복 121 / 351 | 시간 3[s] | 손실 1.18
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 1.17
# | 에폭 4 |  반복 161 / 351 | 시간 4[s] | 손실 1.15
# | 에폭 4 |  반복 181 / 351 | 시간 4[s] | 손실 1.13
# | 에폭 4 |  반복 201 / 351 | 시간 5[s] | 손실 1.12
# | 에폭 4 |  반복 221 / 351 | 시간 6[s] | 손실 1.11
# | 에폭 4 |  반복 241 / 351 | 시간 6[s] | 손실 1.09
# | 에폭 4 |  반복 261 / 351 | 시간 7[s] | 손실 1.08
# | 에폭 4 |  반복 281 / 351 | 시간 7[s] | 손실 1.07
# | 에폭 4 |  반복 301 / 351 | 시간 8[s] | 손실 1.07
# | 에폭 4 |  반복 321 / 351 | 시간 8[s] | 손실 1.05
# | 에폭 4 |  반복 341 / 351 | 시간 9[s] | 손실 1.03
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1196
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 166
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 896
# ---
# Q 761+292
# T 1053
# ☒ 1010
# ---
# Q 830+597
# T 1427
# ☒ 1496
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 5.780%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 5 |  반복 41 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 5 |  반복 81 / 351 | 시간 1[s] | 손실 0.97
# | 에폭 5 |  반복 101 / 351 | 시간 1[s] | 손실 0.95
# | 에폭 5 |  반복 121 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 5 |  반복 141 / 351 | 시간 2[s] | 손실 0.94
# | 에폭 5 |  반복 161 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 5 |  반복 181 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 5 |  반복 201 / 351 | 시간 4[s] | 손실 0.91
# | 에폭 5 |  반복 221 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 5 |  반복 241 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 5 |  반복 261 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 5 |  반복 281 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 5 |  반복 301 / 351 | 시간 6[s] | 손실 0.86
# | 에폭 5 |  반복 321 / 351 | 시간 7[s] | 손실 0.85
# | 에폭 5 |  반복 341 / 351 | 시간 7[s] | 손실 0.84
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1192
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 166
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 860
# ---
# Q 761+292
# T 1053
# ☒ 1066
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 232
# ---
# 검증 정확도 12.460%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 6 |  반복 41 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.81
# | 에폭 6 |  반복 81 / 351 | 시간 1[s] | 손실 0.80
# | 에폭 6 |  반복 101 / 351 | 시간 1[s] | 손실 0.80
# | 에폭 6 |  반복 121 / 351 | 시간 2[s] | 손실 0.79
# | 에폭 6 |  반복 141 / 351 | 시간 2[s] | 손실 0.78
# | 에폭 6 |  반복 161 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 6 |  반복 181 / 351 | 시간 3[s] | 손실 0.77
# | 에폭 6 |  반복 201 / 351 | 시간 3[s] | 손실 0.78
# | 에폭 6 |  반복 221 / 351 | 시간 4[s] | 손실 0.76
# | 에폭 6 |  반복 241 / 351 | 시간 4[s] | 손실 0.75
# | 에폭 6 |  반복 261 / 351 | 시간 4[s] | 손실 0.74
# | 에폭 6 |  반복 281 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 6 |  반복 301 / 351 | 시간 5[s] | 손실 0.73
# | 에폭 6 |  반복 321 / 351 | 시간 6[s] | 손실 0.72
# | 에폭 6 |  반복 341 / 351 | 시간 6[s] | 손실 0.72
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1061
# ---
# Q 830+597
# T 1427
# ☒ 1391
# ---
# Q 26+838
# T 864
# ☒ 866
# ---
# Q 143+93
# T 236
# ☒ 234
# ---
# 검증 정확도 14.260%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.71
# | 에폭 7 |  반복 41 / 351 | 시간 0[s] | 손실 0.70
# | 에폭 7 |  반복 61 / 351 | 시간 1[s] | 손실 0.70
# | 에폭 7 |  반복 81 / 351 | 시간 1[s] | 손실 0.68
# | 에폭 7 |  반복 101 / 351 | 시간 2[s] | 손실 0.68
# | 에폭 7 |  반복 121 / 351 | 시간 2[s] | 손실 0.67
# | 에폭 7 |  반복 141 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 7 |  반복 161 / 351 | 시간 3[s] | 손실 0.67
# | 에폭 7 |  반복 181 / 351 | 시간 4[s] | 손실 0.66
# | 에폭 7 |  반복 201 / 351 | 시간 4[s] | 손실 0.66
# | 에폭 7 |  반복 221 / 351 | 시간 5[s] | 손실 0.66
# | 에폭 7 |  반복 241 / 351 | 시간 5[s] | 손실 0.64
# | 에폭 7 |  반복 261 / 351 | 시간 6[s] | 손실 0.65
# | 에폭 7 |  반복 281 / 351 | 시간 6[s] | 손실 0.64
# | 에폭 7 |  반복 301 / 351 | 시간 7[s] | 손실 0.63
# | 에폭 7 |  반복 321 / 351 | 시간 8[s] | 손실 0.63
# | 에폭 7 |  반복 341 / 351 | 시간 9[s] | 손실 0.62
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1142
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1144
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☒ 866
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 17.500%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.66
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.61
# | 에폭 8 |  반복 41 / 351 | 시간 0[s] | 손실 0.62
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 0.61
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 0.61
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 0.60
# | 에폭 8 |  반복 161 / 351 | 시간 5[s] | 손실 0.59
# | 에폭 8 |  반복 181 / 351 | 시간 6[s] | 손실 0.58
# | 에폭 8 |  반복 201 / 351 | 시간 6[s] | 손실 0.59
# | 에폭 8 |  반복 221 / 351 | 시간 6[s] | 손실 0.60
# | 에폭 8 |  반복 241 / 351 | 시간 7[s] | 손실 0.59
# | 에폭 8 |  반복 261 / 351 | 시간 7[s] | 손실 0.58
# | 에폭 8 |  반복 281 / 351 | 시간 8[s] | 손실 0.59
# | 에폭 8 |  반복 301 / 351 | 시간 9[s] | 손실 0.58
# | 에폭 8 |  반복 321 / 351 | 시간 10[s] | 손실 0.57
# | 에폭 8 |  반복 341 / 351 | 시간 10[s] | 손실 0.57
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1134
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 759
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☒ 866
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 23.080%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.55
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 9 |  반복 41 / 351 | 시간 0[s] | 손실 0.56
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 9 |  반복 81 / 351 | 시간 1[s] | 손실 0.54
# | 에폭 9 |  반복 101 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 9 |  반복 121 / 351 | 시간 2[s] | 손실 0.55
# | 에폭 9 |  반복 141 / 351 | 시간 2[s] | 손실 0.54
# | 에폭 9 |  반복 161 / 351 | 시간 3[s] | 손실 0.55
# | 에폭 9 |  반복 181 / 351 | 시간 3[s] | 손실 0.53
# | 에폭 9 |  반복 201 / 351 | 시간 4[s] | 손실 0.54
# | 에폭 9 |  반복 221 / 351 | 시간 4[s] | 손실 0.54
# | 에폭 9 |  반복 241 / 351 | 시간 4[s] | 손실 0.53
# | 에폭 9 |  반복 261 / 351 | 시간 5[s] | 손실 0.53
# | 에폭 9 |  반복 281 / 351 | 시간 5[s] | 손실 0.54
# | 에폭 9 |  반복 301 / 351 | 시간 6[s] | 손실 0.54
# | 에폭 9 |  반복 321 / 351 | 시간 7[s] | 손실 0.53
# | 에폭 9 |  반복 341 / 351 | 시간 7[s] | 손실 0.53
# Q 77+85
# T 162
# ☒ 158
# ---
# Q 975+164
# T 1139
# ☒ 1142
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 854
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 26.540%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 10 |  반복 41 / 351 | 시간 0[s] | 손실 0.52
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.55
# | 에폭 10 |  반복 81 / 351 | 시간 1[s] | 손실 0.52
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.51
# | 에폭 10 |  반복 121 / 351 | 시간 2[s] | 손실 0.50
# | 에폭 10 |  반복 141 / 351 | 시간 3[s] | 손실 0.51
# | 에폭 10 |  반복 161 / 351 | 시간 3[s] | 손실 0.52
# | 에폭 10 |  반복 181 / 351 | 시간 4[s] | 손실 0.53
# | 에폭 10 |  반복 201 / 351 | 시간 4[s] | 손실 0.50
# | 에폭 10 |  반복 221 / 351 | 시간 5[s] | 손실 0.50
# | 에폭 10 |  반복 241 / 351 | 시간 5[s] | 손실 0.50
# | 에폭 10 |  반복 261 / 351 | 시간 6[s] | 손실 0.50
# | 에폭 10 |  반복 281 / 351 | 시간 6[s] | 손실 0.49
# | 에폭 10 |  반복 301 / 351 | 시간 7[s] | 손실 0.48
# | 에폭 10 |  반복 321 / 351 | 시간 7[s] | 손실 0.48
# | 에폭 10 |  반복 341 / 351 | 시간 8[s] | 손실 0.48
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 664
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 29.820%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.47
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.48
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 11 |  반복 61 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 11 |  반복 81 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 11 |  반복 101 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 11 |  반복 121 / 351 | 시간 3[s] | 손실 0.47
# | 에폭 11 |  반복 141 / 351 | 시간 4[s] | 손실 0.47
# | 에폭 11 |  반복 161 / 351 | 시간 4[s] | 손실 0.48
# | 에폭 11 |  반복 181 / 351 | 시간 5[s] | 손실 0.48
# | 에폭 11 |  반복 201 / 351 | 시간 5[s] | 손실 0.47
# | 에폭 11 |  반복 221 / 351 | 시간 6[s] | 손실 0.47
# | 에폭 11 |  반복 241 / 351 | 시간 6[s] | 손실 0.46
# | 에폭 11 |  반복 261 / 351 | 시간 7[s] | 손실 0.46
# | 에폭 11 |  반복 281 / 351 | 시간 8[s] | 손실 0.46
# | 에폭 11 |  반복 301 / 351 | 시간 8[s] | 손실 0.48
# | 에폭 11 |  반복 321 / 351 | 시간 9[s] | 손실 0.45
# | 에폭 11 |  반복 341 / 351 | 시간 9[s] | 손실 0.45
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1140
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☒ 866
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 28.480%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.46
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.45
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.45
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.46
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.45
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 12 |  반복 141 / 351 | 시간 4[s] | 손실 0.46
# | 에폭 12 |  반복 161 / 351 | 시간 4[s] | 손실 0.45
# | 에폭 12 |  반복 181 / 351 | 시간 5[s] | 손실 0.44
# | 에폭 12 |  반복 201 / 351 | 시간 6[s] | 손실 0.45
# | 에폭 12 |  반복 221 / 351 | 시간 7[s] | 손실 0.44
# | 에폭 12 |  반복 241 / 351 | 시간 7[s] | 손실 0.43
# | 에폭 12 |  반복 261 / 351 | 시간 8[s] | 손실 0.43
# | 에폭 12 |  반복 281 / 351 | 시간 8[s] | 손실 0.44
# | 에폭 12 |  반복 301 / 351 | 시간 9[s] | 손실 0.45
# | 에폭 12 |  반복 321 / 351 | 시간 9[s] | 손실 0.44
# | 에폭 12 |  반복 341 / 351 | 시간 10[s] | 손실 0.43
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 36.640%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.43
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 13 |  반복 61 / 351 | 시간 1[s] | 손실 0.42
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.42
# | 에폭 13 |  반복 101 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 0.43
# | 에폭 13 |  반복 141 / 351 | 시간 4[s] | 손실 0.41
# | 에폭 13 |  반복 161 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 13 |  반복 181 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 13 |  반복 201 / 351 | 시간 6[s] | 손실 0.42
# | 에폭 13 |  반복 221 / 351 | 시간 6[s] | 손실 0.43
# | 에폭 13 |  반복 241 / 351 | 시간 7[s] | 손실 0.43
# | 에폭 13 |  반복 261 / 351 | 시간 7[s] | 손실 0.41
# | 에폭 13 |  반복 281 / 351 | 시간 8[s] | 손실 0.42
# | 에폭 13 |  반복 301 / 351 | 시간 9[s] | 손실 0.41
# | 에폭 13 |  반복 321 / 351 | 시간 9[s] | 손실 0.43
# | 에폭 13 |  반복 341 / 351 | 시간 10[s] | 손실 0.40
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1140
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 39.420%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.41
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.41
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.40
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.40
# | 에폭 14 |  반복 101 / 351 | 시간 3[s] | 손실 0.41
# | 에폭 14 |  반복 121 / 351 | 시간 3[s] | 손실 0.39
# | 에폭 14 |  반복 141 / 351 | 시간 4[s] | 손실 0.39
# | 에폭 14 |  반복 161 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 14 |  반복 181 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 14 |  반복 201 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 14 |  반복 221 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 14 |  반복 241 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 14 |  반복 261 / 351 | 시간 7[s] | 손실 0.40
# | 에폭 14 |  반복 281 / 351 | 시간 8[s] | 손실 0.41
# | 에폭 14 |  반복 301 / 351 | 시간 8[s] | 손실 0.39
# | 에폭 14 |  반복 321 / 351 | 시간 9[s] | 손실 0.39
# | 에폭 14 |  반복 341 / 351 | 시간 10[s] | 손실 0.39
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 36.640%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.38
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.39
# | 에폭 15 |  반복 41 / 351 | 시간 1[s] | 손실 0.39
# | 에폭 15 |  반복 61 / 351 | 시간 2[s] | 손실 0.38
# | 에폭 15 |  반복 81 / 351 | 시간 2[s] | 손실 0.38
# | 에폭 15 |  반복 101 / 351 | 시간 3[s] | 손실 0.38
# | 에폭 15 |  반복 121 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 15 |  반복 141 / 351 | 시간 4[s] | 손실 0.38
# | 에폭 15 |  반복 161 / 351 | 시간 5[s] | 손실 0.38
# | 에폭 15 |  반복 181 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 15 |  반복 201 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 15 |  반복 221 / 351 | 시간 7[s] | 손실 0.39
# | 에폭 15 |  반복 241 / 351 | 시간 7[s] | 손실 0.38
# | 에폭 15 |  반복 261 / 351 | 시간 8[s] | 손실 0.37
# | 에폭 15 |  반복 281 / 351 | 시간 9[s] | 손실 0.37
# | 에폭 15 |  반복 301 / 351 | 시간 9[s] | 손실 0.39
# | 에폭 15 |  반복 321 / 351 | 시간 10[s] | 손실 0.39
# | 에폭 15 |  반복 341 / 351 | 시간 10[s] | 손실 0.37
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 420
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1431
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 41.100%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.37
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 16 |  반복 121 / 351 | 시간 3[s] | 손실 0.37
# | 에폭 16 |  반복 141 / 351 | 시간 4[s] | 손실 0.36
# | 에폭 16 |  반복 161 / 351 | 시간 5[s] | 손실 0.37
# | 에폭 16 |  반복 181 / 351 | 시간 5[s] | 손실 0.36
# | 에폭 16 |  반복 201 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 16 |  반복 221 / 351 | 시간 6[s] | 손실 0.38
# | 에폭 16 |  반복 241 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 16 |  반복 261 / 351 | 시간 7[s] | 손실 0.35
# | 에폭 16 |  반복 281 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 16 |  반복 301 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 16 |  반복 321 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 16 |  반복 341 / 351 | 시간 10[s] | 손실 0.37
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1142
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1430
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 42.700%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.36
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.35
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.36
# | 에폭 17 |  반복 101 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 17 |  반복 121 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 17 |  반복 141 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 17 |  반복 161 / 351 | 시간 5[s] | 손실 0.34
# | 에폭 17 |  반복 181 / 351 | 시간 5[s] | 손실 0.35
# | 에폭 17 |  반복 201 / 351 | 시간 6[s] | 손실 0.35
# | 에폭 17 |  반복 221 / 351 | 시간 6[s] | 손실 0.34
# | 에폭 17 |  반복 241 / 351 | 시간 7[s] | 손실 0.35
# | 에폭 17 |  반복 261 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 17 |  반복 281 / 351 | 시간 8[s] | 손실 0.37
# | 에폭 17 |  반복 301 / 351 | 시간 9[s] | 손실 0.37
# | 에폭 17 |  반복 321 / 351 | 시간 9[s] | 손실 0.37
# | 에폭 17 |  반복 341 / 351 | 시간 10[s] | 손실 0.36
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 42.840%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.36
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.35
# | 에폭 18 |  반복 81 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 18 |  반복 101 / 351 | 시간 3[s] | 손실 0.34
# | 에폭 18 |  반복 121 / 351 | 시간 3[s] | 손실 0.33
# | 에폭 18 |  반복 141 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 18 |  반복 161 / 351 | 시간 4[s] | 손실 0.34
# | 에폭 18 |  반복 181 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 18 |  반복 201 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 18 |  반복 221 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 18 |  반복 241 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 18 |  반복 261 / 351 | 시간 7[s] | 손실 0.33
# | 에폭 18 |  반복 281 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 18 |  반복 301 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 18 |  반복 321 / 351 | 시간 9[s] | 손실 0.35
# | 에폭 18 |  반복 341 / 351 | 시간 10[s] | 손실 0.35
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 40.640%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.34
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.34
# | 에폭 19 |  반복 61 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 0.34
# | 에폭 19 |  반복 101 / 351 | 시간 3[s] | 손실 0.32
# | 에폭 19 |  반복 121 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 19 |  반복 141 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 19 |  반복 161 / 351 | 시간 5[s] | 손실 0.31
# | 에폭 19 |  반복 181 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 19 |  반복 201 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 19 |  반복 221 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 19 |  반복 241 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 19 |  반복 261 / 351 | 시간 8[s] | 손실 0.33
# | 에폭 19 |  반복 281 / 351 | 시간 9[s] | 손실 0.32
# | 에폭 19 |  반복 301 / 351 | 시간 11[s] | 손실 0.32
# | 에폭 19 |  반복 321 / 351 | 시간 11[s] | 손실 0.33
# | 에폭 19 |  반복 341 / 351 | 시간 12[s] | 손실 0.33
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1140
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1430
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 47.520%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.33
# | 에폭 20 |  반복 61 / 351 | 시간 2[s] | 손실 0.33
# | 에폭 20 |  반복 81 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 20 |  반복 101 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 20 |  반복 121 / 351 | 시간 4[s] | 손실 0.33
# | 에폭 20 |  반복 141 / 351 | 시간 4[s] | 손실 0.32
# | 에폭 20 |  반복 161 / 351 | 시간 5[s] | 손실 0.33
# | 에폭 20 |  반복 181 / 351 | 시간 6[s] | 손실 0.31
# | 에폭 20 |  반복 201 / 351 | 시간 7[s] | 손실 0.30
# | 에폭 20 |  반복 221 / 351 | 시간 8[s] | 손실 0.32
# | 에폭 20 |  반복 241 / 351 | 시간 9[s] | 손실 0.33
# | 에폭 20 |  반복 261 / 351 | 시간 10[s] | 손실 0.35
# | 에폭 20 |  반복 281 / 351 | 시간 10[s] | 손실 0.36
# | 에폭 20 |  반복 301 / 351 | 시간 11[s] | 손실 0.34
# | 에폭 20 |  반복 321 / 351 | 시간 12[s] | 손실 0.32
# | 에폭 20 |  반복 341 / 351 | 시간 13[s] | 손실 0.32
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1051
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 50.100%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 0.30
# | 에폭 21 |  반복 61 / 351 | 시간 2[s] | 손실 0.30
# | 에폭 21 |  반복 81 / 351 | 시간 4[s] | 손실 0.32
# | 에폭 21 |  반복 101 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 21 |  반복 121 / 351 | 시간 6[s] | 손실 0.31
# | 에폭 21 |  반복 141 / 351 | 시간 6[s] | 손실 0.30
# | 에폭 21 |  반복 161 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 21 |  반복 181 / 351 | 시간 8[s] | 손실 0.31
# | 에폭 21 |  반복 201 / 351 | 시간 9[s] | 손실 0.31
# | 에폭 21 |  반복 221 / 351 | 시간 9[s] | 손실 0.32
# | 에폭 21 |  반복 241 / 351 | 시간 10[s] | 손실 0.31
# | 에폭 21 |  반복 261 / 351 | 시간 11[s] | 손실 0.29
# | 에폭 21 |  반복 281 / 351 | 시간 11[s] | 손실 0.30
# | 에폭 21 |  반복 301 / 351 | 시간 12[s] | 손실 0.29
# | 에폭 21 |  반복 321 / 351 | 시간 13[s] | 손실 0.29
# | 에폭 21 |  반복 341 / 351 | 시간 13[s] | 손실 0.29
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 51.000%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.29
# | 에폭 22 |  반복 81 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.28
# | 에폭 22 |  반복 121 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 22 |  반복 141 / 351 | 시간 3[s] | 손실 0.31
# | 에폭 22 |  반복 161 / 351 | 시간 4[s] | 손실 0.31
# | 에폭 22 |  반복 181 / 351 | 시간 4[s] | 손실 0.30
# | 에폭 22 |  반복 201 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 22 |  반복 221 / 351 | 시간 5[s] | 손실 0.32
# | 에폭 22 |  반복 241 / 351 | 시간 6[s] | 손실 0.33
# | 에폭 22 |  반복 261 / 351 | 시간 6[s] | 손실 0.32
# | 에폭 22 |  반복 281 / 351 | 시간 7[s] | 손실 0.31
# | 에폭 22 |  반복 301 / 351 | 시간 7[s] | 손실 0.30
# | 에폭 22 |  반복 321 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 22 |  반복 341 / 351 | 시간 8[s] | 손실 0.31
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1430
# ---
# Q 26+838
# T 864
# ☒ 865
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 47.720%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 23 |  반복 81 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 23 |  반복 101 / 351 | 시간 2[s] | 손실 0.27
# | 에폭 23 |  반복 121 / 351 | 시간 3[s] | 손실 0.28
# | 에폭 23 |  반복 141 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 23 |  반복 161 / 351 | 시간 4[s] | 손실 0.30
# | 에폭 23 |  반복 181 / 351 | 시간 5[s] | 손실 0.30
# | 에폭 23 |  반복 201 / 351 | 시간 5[s] | 손실 0.29
# | 에폭 23 |  반복 221 / 351 | 시간 6[s] | 손실 0.29
# | 에폭 23 |  반복 241 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 23 |  반복 261 / 351 | 시간 7[s] | 손실 0.28
# | 에폭 23 |  반복 281 / 351 | 시간 7[s] | 손실 0.30
# | 에폭 23 |  반복 301 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 23 |  반복 321 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 23 |  반복 341 / 351 | 시간 9[s] | 손실 0.28
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1142
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☒ 866
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 45.220%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 24 |  반복 61 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 24 |  반복 81 / 351 | 시간 2[s] | 손실 0.30
# | 에폭 24 |  반복 101 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 24 |  반복 121 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 24 |  반복 141 / 351 | 시간 4[s] | 손실 0.29
# | 에폭 24 |  반복 161 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 24 |  반복 181 / 351 | 시간 5[s] | 손실 0.29
# | 에폭 24 |  반복 201 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 24 |  반복 221 / 351 | 시간 6[s] | 손실 0.28
# | 에폭 24 |  반복 241 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 24 |  반복 261 / 351 | 시간 7[s] | 손실 0.29
# | 에폭 24 |  반복 281 / 351 | 시간 8[s] | 손실 0.29
# | 에폭 24 |  반복 301 / 351 | 시간 8[s] | 손실 0.28
# | 에폭 24 |  반복 321 / 351 | 시간 9[s] | 손실 0.27
# | 에폭 24 |  반복 341 / 351 | 시간 9[s] | 손실 0.29
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1054
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 51.740%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.29
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 0.28
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.26
# | 에폭 25 |  반복 81 / 351 | 시간 2[s] | 손실 0.26
# | 에폭 25 |  반복 101 / 351 | 시간 3[s] | 손실 0.27
# | 에폭 25 |  반복 121 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 25 |  반복 141 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 25 |  반복 161 / 351 | 시간 4[s] | 손실 0.28
# | 에폭 25 |  반복 181 / 351 | 시간 5[s] | 손실 0.28
# | 에폭 25 |  반복 201 / 351 | 시간 5[s] | 손실 0.27
# | 에폭 25 |  반복 221 / 351 | 시간 6[s] | 손실 0.29
# | 에폭 25 |  반복 241 / 351 | 시간 6[s] | 손실 0.27
# | 에폭 25 |  반복 261 / 351 | 시간 7[s] | 손실 0.28
# | 에폭 25 |  반복 281 / 351 | 시간 8[s] | 손실 0.28
# | 에폭 25 |  반복 301 / 351 | 시간 8[s] | 손실 0.27
# | 에폭 25 |  반복 321 / 351 | 시간 9[s] | 손실 0.28
# | 에폭 25 |  반복 341 / 351 | 시간 9[s] | 손실 0.28
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1140
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1426
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 54.120%

# %% [markdown]
# ### Peeky

# %%
import sys
sys.path.append('..')
from common.time_layers import *
#from seq2seq import Seq2seq, Encoder


class PeekyDecoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H + D, 4 * H) / np.sqrt(H + D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H + H, V) / np.sqrt(H + H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None

    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H)
        out = np.concatenate((hs, out), axis=2)

        out = self.lstm.forward(out)
        out = np.concatenate((hs, out), axis=2)

        score = self.affine.forward(out)
        self.cache = H
        return score

    def backward(self, dscore):
        H = self.cache

        dout = self.affine.backward(dscore)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H]
        dout = self.lstm.backward(dout)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H]
        self.embed.backward(dembed)

        dhs = dhs0 + dhs1
        dh = self.lstm.dh + np.sum(dhs, axis=1)
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        char_id = start_id
        self.lstm.set_state(h)

        H = h.shape[1]
        peeky_h = h.reshape(1, 1, H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1, 1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2)
            out = self.lstm.forward(out)
            out = np.concatenate((peeky_h, out), axis=2)
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten())
            sampled.append(char_id)

        return sampled


class PeekySeq2seq(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = PeekyDecoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq


# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 반전 여부 설정 =============================================
is_reverse = True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 일반 혹은 엿보기(Peeky) 설정 =====================================
# model = Seq2seq(vocab_size, wordvec_size, hidden_size)
model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))

# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.57
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.48
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 2.20
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.99
# | 에폭 1 |  반복 81 / 351 | 시간 2[s] | 손실 1.89
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.82
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.82
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.80
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 4[s] | 손실 1.78
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.75
# | 에폭 1 |  반복 281 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 7[s] | 손실 1.73
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 1.73
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1013
# ---
# Q 582+84
# T 666
# ☒ 102
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 1023
# ---
# Q 600+257
# T 857
# ☒ 1023
# ---
# Q 761+292
# T 1053
# ☒ 1023
# ---
# Q 830+597
# T 1427
# ☒ 1111
# ---
# Q 26+838
# T 864
# ☒ 102
# ---
# Q 143+93
# T 236
# ☒ 102
# ---
# 검증 정확도 0.280%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.71
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.71
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.70
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.68
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.69
# | 에폭 2 |  반복 141 / 351 | 시간 3[s] | 손실 1.68
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.67
# | 에폭 2 |  반복 181 / 351 | 시간 4[s] | 손실 1.67
# | 에폭 2 |  반복 201 / 351 | 시간 5[s] | 손실 1.65
# | 에폭 2 |  반복 221 / 351 | 시간 5[s] | 손실 1.65
# | 에폭 2 |  반복 241 / 351 | 시간 5[s] | 손실 1.65
# | 에폭 2 |  반복 261 / 351 | 시간 6[s] | 손실 1.63
# | 에폭 2 |  반복 281 / 351 | 시간 6[s] | 손실 1.62
# | 에폭 2 |  반복 301 / 351 | 시간 7[s] | 손실 1.61
# | 에폭 2 |  반복 321 / 351 | 시간 7[s] | 손실 1.61
# | 에폭 2 |  반복 341 / 351 | 시간 8[s] | 손실 1.60
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1200
# ---
# Q 582+84
# T 666
# ☒ 690
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 690
# ---
# Q 600+257
# T 857
# ☒ 999
# ---
# Q 761+292
# T 1053
# ☒ 1029
# ---
# Q 830+597
# T 1427
# ☒ 1240
# ---
# Q 26+838
# T 864
# ☒ 792
# ---
# Q 143+93
# T 236
# ☒ 290
# ---
# 검증 정확도 0.400%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.58
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.59
# | 에폭 3 |  반복 41 / 351 | 시간 0[s] | 손실 1.58
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.56
# | 에폭 3 |  반복 81 / 351 | 시간 1[s] | 손실 1.55
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.53
# | 에폭 3 |  반복 121 / 351 | 시간 3[s] | 손실 1.51
# | 에폭 3 |  반복 141 / 351 | 시간 3[s] | 손실 1.50
# | 에폭 3 |  반복 161 / 351 | 시간 4[s] | 손실 1.49
# | 에폭 3 |  반복 181 / 351 | 시간 4[s] | 손실 1.47
# | 에폭 3 |  반복 201 / 351 | 시간 5[s] | 손실 1.46
# | 에폭 3 |  반복 221 / 351 | 시간 5[s] | 손실 1.43
# | 에폭 3 |  반복 241 / 351 | 시간 6[s] | 손실 1.42
# | 에폭 3 |  반복 261 / 351 | 시간 6[s] | 손실 1.41
# | 에폭 3 |  반복 281 / 351 | 시간 7[s] | 손실 1.39
# | 에폭 3 |  반복 301 / 351 | 시간 7[s] | 손실 1.37
# | 에폭 3 |  반복 321 / 351 | 시간 8[s] | 손실 1.36
# | 에폭 3 |  반복 341 / 351 | 시간 8[s] | 손실 1.35
# Q 77+85
# T 162
# ☒ 154
# ---
# Q 975+164
# T 1139
# ☒ 1033
# ---
# Q 582+84
# T 666
# ☒ 644
# ---
# Q 8+155
# T 163
# ☒ 161
# ---
# Q 367+55
# T 422
# ☒ 433
# ---
# Q 600+257
# T 857
# ☒ 818
# ---
# Q 761+292
# T 1053
# ☒ 1018
# ---
# Q 830+597
# T 1427
# ☒ 1344
# ---
# Q 26+838
# T 864
# ☒ 834
# ---
# Q 143+93
# T 236
# ☒ 211
# ---
# 검증 정확도 1.600%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.32
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.32
# | 에폭 4 |  반복 41 / 351 | 시간 1[s] | 손실 1.30
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.30
# | 에폭 4 |  반복 81 / 351 | 시간 2[s] | 손실 1.28
# | 에폭 4 |  반복 101 / 351 | 시간 3[s] | 손실 1.27
# | 에폭 4 |  반복 121 / 351 | 시간 4[s] | 손실 1.25
# | 에폭 4 |  반복 141 / 351 | 시간 5[s] | 손실 1.24
# | 에폭 4 |  반복 161 / 351 | 시간 5[s] | 손실 1.22
# | 에폭 4 |  반복 181 / 351 | 시간 6[s] | 손실 1.21
# | 에폭 4 |  반복 201 / 351 | 시간 6[s] | 손실 1.20
# | 에폭 4 |  반복 221 / 351 | 시간 7[s] | 손실 1.20
# | 에폭 4 |  반복 241 / 351 | 시간 7[s] | 손실 1.17
# | 에폭 4 |  반복 261 / 351 | 시간 8[s] | 손실 1.16
# | 에폭 4 |  반복 281 / 351 | 시간 8[s] | 손실 1.14
# | 에폭 4 |  반복 301 / 351 | 시간 9[s] | 손실 1.12
# | 에폭 4 |  반복 321 / 351 | 시간 10[s] | 손실 1.11
# | 에폭 4 |  반복 341 / 351 | 시간 10[s] | 손실 1.10
# Q 77+85
# T 162
# ☒ 158
# ---
# Q 975+164
# T 1139
# ☒ 1123
# ---
# Q 582+84
# T 666
# ☒ 657
# ---
# Q 8+155
# T 163
# ☒ 165
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 777
# ---
# Q 761+292
# T 1053
# ☒ 1023
# ---
# Q 830+597
# T 1427
# ☒ 1388
# ---
# Q 26+838
# T 864
# ☒ 887
# ---
# Q 143+93
# T 236
# ☒ 223
# ---
# 검증 정확도 5.140%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.08
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.07
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.05
# | 에폭 5 |  반복 61 / 351 | 시간 1[s] | 손실 1.04
# | 에폭 5 |  반복 81 / 351 | 시간 2[s] | 손실 1.02
# | 에폭 5 |  반복 101 / 351 | 시간 2[s] | 손실 1.01
# | 에폭 5 |  반복 121 / 351 | 시간 3[s] | 손실 1.00
# | 에폭 5 |  반복 141 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 5 |  반복 161 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 5 |  반복 181 / 351 | 시간 5[s] | 손실 0.96
# | 에폭 5 |  반복 201 / 351 | 시간 6[s] | 손실 0.95
# | 에폭 5 |  반복 221 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 5 |  반복 241 / 351 | 시간 7[s] | 손실 0.92
# | 에폭 5 |  반복 261 / 351 | 시간 8[s] | 손실 0.91
# | 에폭 5 |  반복 281 / 351 | 시간 9[s] | 손실 0.90
# | 에폭 5 |  반복 301 / 351 | 시간 9[s] | 손실 0.89
# | 에폭 5 |  반복 321 / 351 | 시간 10[s] | 손실 0.88
# | 에폭 5 |  반복 341 / 351 | 시간 10[s] | 손실 0.87
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1135
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 169
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 861
# ---
# Q 761+292
# T 1053
# ☒ 1045
# ---
# Q 830+597
# T 1427
# ☒ 1324
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 9.380%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 6 |  반복 61 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 6 |  반복 101 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 6 |  반복 121 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 6 |  반복 141 / 351 | 시간 4[s] | 손실 0.79
# | 에폭 6 |  반복 161 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 6 |  반복 181 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 6 |  반복 201 / 351 | 시간 6[s] | 손실 0.76
# | 에폭 6 |  반복 221 / 351 | 시간 7[s] | 손실 0.76
# | 에폭 6 |  반복 241 / 351 | 시간 8[s] | 손실 0.74
# | 에폭 6 |  반복 261 / 351 | 시간 8[s] | 손실 0.74
# | 에폭 6 |  반복 281 / 351 | 시간 10[s] | 손실 0.73
# | 에폭 6 |  반복 301 / 351 | 시간 10[s] | 손실 0.72
# | 에폭 6 |  반복 321 / 351 | 시간 11[s] | 손실 0.72
# | 에폭 6 |  반복 341 / 351 | 시간 12[s] | 손실 0.71
# Q 77+85
# T 162
# ☒ 163
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 166
# ---
# Q 367+55
# T 422
# ☒ 423
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1048
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 873
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 15.040%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.68
# | 에폭 7 |  반복 21 / 351 | 시간 0[s] | 손실 0.69
# | 에폭 7 |  반복 41 / 351 | 시간 1[s] | 손실 0.67
# | 에폭 7 |  반복 61 / 351 | 시간 2[s] | 손실 0.66
# | 에폭 7 |  반복 81 / 351 | 시간 3[s] | 손실 0.66
# | 에폭 7 |  반복 101 / 351 | 시간 4[s] | 손실 0.65
# | 에폭 7 |  반복 121 / 351 | 시간 5[s] | 손실 0.65
# | 에폭 7 |  반복 141 / 351 | 시간 5[s] | 손실 0.64
# | 에폭 7 |  반복 161 / 351 | 시간 6[s] | 손실 0.63
# | 에폭 7 |  반복 181 / 351 | 시간 7[s] | 손실 0.61
# | 에폭 7 |  반복 201 / 351 | 시간 7[s] | 손실 0.61
# | 에폭 7 |  반복 221 / 351 | 시간 8[s] | 손실 0.60
# | 에폭 7 |  반복 241 / 351 | 시간 8[s] | 손실 0.57
# | 에폭 7 |  반복 261 / 351 | 시간 9[s] | 손실 0.57
# | 에폭 7 |  반복 281 / 351 | 시간 9[s] | 손실 0.57
# | 에폭 7 |  반복 301 / 351 | 시간 10[s] | 손실 0.55
# | 에폭 7 |  반복 321 / 351 | 시간 10[s] | 손실 0.54
# | 에폭 7 |  반복 341 / 351 | 시간 11[s] | 손실 0.53
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 156
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 858
# ---
# Q 761+292
# T 1053
# ☒ 1052
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# 검증 정확도 39.100%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.51
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 0.50
# | 에폭 8 |  반복 41 / 351 | 시간 1[s] | 손실 0.49
# | 에폭 8 |  반복 61 / 351 | 시간 1[s] | 손실 0.48
# | 에폭 8 |  반복 81 / 351 | 시간 2[s] | 손실 0.47
# | 에폭 8 |  반복 101 / 351 | 시간 2[s] | 손실 0.46
# | 에폭 8 |  반복 121 / 351 | 시간 3[s] | 손실 0.46
# | 에폭 8 |  반복 141 / 351 | 시간 3[s] | 손실 0.44
# | 에폭 8 |  반복 161 / 351 | 시간 4[s] | 손실 0.41
# | 에폭 8 |  반복 181 / 351 | 시간 5[s] | 손실 0.42
# | 에폭 8 |  반복 201 / 351 | 시간 5[s] | 손실 0.41
# | 에폭 8 |  반복 221 / 351 | 시간 6[s] | 손실 0.40
# | 에폭 8 |  반복 241 / 351 | 시간 6[s] | 손실 0.39
# | 에폭 8 |  반복 261 / 351 | 시간 7[s] | 손실 0.37
# | 에폭 8 |  반복 281 / 351 | 시간 7[s] | 손실 0.36
# | 에폭 8 |  반복 301 / 351 | 시간 8[s] | 손실 0.36
# | 에폭 8 |  반복 321 / 351 | 시간 8[s] | 손실 0.35
# | 에폭 8 |  반복 341 / 351 | 시간 9[s] | 손실 0.34
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 657
# ---
# Q 8+155
# T 163
# ☒ 155
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1438
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 65.060%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.32
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 0.31
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 0.31
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.29
# | 에폭 9 |  반복 101 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 0.29
# | 에폭 9 |  반복 141 / 351 | 시간 4[s] | 손실 0.27
# | 에폭 9 |  반복 161 / 351 | 시간 5[s] | 손실 0.27
# | 에폭 9 |  반복 181 / 351 | 시간 5[s] | 손실 0.26
# | 에폭 9 |  반복 201 / 351 | 시간 6[s] | 손실 0.25
# | 에폭 9 |  반복 221 / 351 | 시간 6[s] | 손실 0.25
# | 에폭 9 |  반복 241 / 351 | 시간 7[s] | 손실 0.24
# | 에폭 9 |  반복 261 / 351 | 시간 8[s] | 손실 0.24
# | 에폭 9 |  반복 281 / 351 | 시간 8[s] | 손실 0.23
# | 에폭 9 |  반복 301 / 351 | 시간 9[s] | 손실 0.22
# | 에폭 9 |  반복 321 / 351 | 시간 9[s] | 손실 0.22
# | 에폭 9 |  반복 341 / 351 | 시간 10[s] | 손실 0.21
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1140
# ---
# Q 582+84
# T 666
# ☒ 657
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 83.280%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.22
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.20
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.20
# | 에폭 10 |  반복 61 / 351 | 시간 1[s] | 손실 0.20
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.18
# | 에폭 10 |  반복 101 / 351 | 시간 2[s] | 손실 0.17
# | 에폭 10 |  반복 121 / 351 | 시간 3[s] | 손실 0.18
# | 에폭 10 |  반복 141 / 351 | 시간 4[s] | 손실 0.17
# | 에폭 10 |  반복 161 / 351 | 시간 4[s] | 손실 0.17
# | 에폭 10 |  반복 181 / 351 | 시간 5[s] | 손실 0.17
# | 에폭 10 |  반복 201 / 351 | 시간 5[s] | 손실 0.17
# | 에폭 10 |  반복 221 / 351 | 시간 6[s] | 손실 0.16
# | 에폭 10 |  반복 241 / 351 | 시간 7[s] | 손실 0.15
# | 에폭 10 |  반복 261 / 351 | 시간 7[s] | 손실 0.15
# | 에폭 10 |  반복 281 / 351 | 시간 8[s] | 손실 0.15
# | 에폭 10 |  반복 301 / 351 | 시간 8[s] | 손실 0.15
# | 에폭 10 |  반복 321 / 351 | 시간 9[s] | 손실 0.14
# | 에폭 10 |  반복 341 / 351 | 시간 10[s] | 손실 0.14
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 656
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 88.400%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.13
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.13
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.13
# | 에폭 11 |  반복 61 / 351 | 시간 2[s] | 손실 0.12
# | 에폭 11 |  반복 81 / 351 | 시간 3[s] | 손실 0.12
# | 에폭 11 |  반복 101 / 351 | 시간 3[s] | 손실 0.12
# | 에폭 11 |  반복 121 / 351 | 시간 4[s] | 손실 0.11
# | 에폭 11 |  반복 141 / 351 | 시간 4[s] | 손실 0.12
# | 에폭 11 |  반복 161 / 351 | 시간 5[s] | 손실 0.11
# | 에폭 11 |  반복 181 / 351 | 시간 5[s] | 손실 0.11
# | 에폭 11 |  반복 201 / 351 | 시간 6[s] | 손실 0.12
# | 에폭 11 |  반복 221 / 351 | 시간 7[s] | 손실 0.11
# | 에폭 11 |  반복 241 / 351 | 시간 7[s] | 손실 0.11
# | 에폭 11 |  반복 261 / 351 | 시간 8[s] | 손실 0.10
# | 에폭 11 |  반복 281 / 351 | 시간 8[s] | 손실 0.10
# | 에폭 11 |  반복 301 / 351 | 시간 9[s] | 손실 0.10
# | 에폭 11 |  반복 321 / 351 | 시간 10[s] | 손실 0.09
# | 에폭 11 |  반복 341 / 351 | 시간 10[s] | 손실 0.09
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 90.940%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.09
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.09
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.09
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.09
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.09
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.08
# | 에폭 12 |  반복 121 / 351 | 시간 3[s] | 손실 0.08
# | 에폭 12 |  반복 141 / 351 | 시간 4[s] | 손실 0.08
# | 에폭 12 |  반복 161 / 351 | 시간 4[s] | 손실 0.08
# | 에폭 12 |  반복 181 / 351 | 시간 5[s] | 손실 0.08
# | 에폭 12 |  반복 201 / 351 | 시간 5[s] | 손실 0.08
# | 에폭 12 |  반복 221 / 351 | 시간 7[s] | 손실 0.09
# | 에폭 12 |  반복 241 / 351 | 시간 7[s] | 손실 0.09
# | 에폭 12 |  반복 261 / 351 | 시간 8[s] | 손실 0.09
# | 에폭 12 |  반복 281 / 351 | 시간 8[s] | 손실 0.08
# | 에폭 12 |  반복 301 / 351 | 시간 9[s] | 손실 0.08
# | 에폭 12 |  반복 321 / 351 | 시간 10[s] | 손실 0.07
# | 에폭 12 |  반복 341 / 351 | 시간 11[s] | 손실 0.08
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 92.220%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.07
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.07
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.07
# | 에폭 13 |  반복 61 / 351 | 시간 2[s] | 손실 0.07
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.06
# | 에폭 13 |  반복 101 / 351 | 시간 3[s] | 손실 0.06
# | 에폭 13 |  반복 121 / 351 | 시간 4[s] | 손실 0.07
# | 에폭 13 |  반복 141 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 13 |  반복 161 / 351 | 시간 5[s] | 손실 0.06
# | 에폭 13 |  반복 181 / 351 | 시간 6[s] | 손실 0.06
# | 에폭 13 |  반복 201 / 351 | 시간 7[s] | 손실 0.06
# | 에폭 13 |  반복 221 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 13 |  반복 241 / 351 | 시간 9[s] | 손실 0.06
# | 에폭 13 |  반복 261 / 351 | 시간 10[s] | 손실 0.06
# | 에폭 13 |  반복 281 / 351 | 시간 10[s] | 손실 0.06
# | 에폭 13 |  반복 301 / 351 | 시간 11[s] | 손실 0.05
# | 에폭 13 |  반복 321 / 351 | 시간 12[s] | 손실 0.05
# | 에폭 13 |  반복 341 / 351 | 시간 13[s] | 손실 0.06
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 94.400%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 14 |  반복 41 / 351 | 시간 1[s] | 손실 0.05
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.05
# | 에폭 14 |  반복 81 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 14 |  반복 101 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 14 |  반복 121 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 14 |  반복 141 / 351 | 시간 4[s] | 손실 0.05
# | 에폭 14 |  반복 161 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 14 |  반복 181 / 351 | 시간 5[s] | 손실 0.05
# | 에폭 14 |  반복 201 / 351 | 시간 7[s] | 손실 0.05
# | 에폭 14 |  반복 221 / 351 | 시간 8[s] | 손실 0.06
# | 에폭 14 |  반복 241 / 351 | 시간 9[s] | 손실 0.06
# | 에폭 14 |  반복 261 / 351 | 시간 11[s] | 손실 0.07
# | 에폭 14 |  반복 281 / 351 | 시간 12[s] | 손실 0.06
# | 에폭 14 |  반복 301 / 351 | 시간 13[s] | 손실 0.06
# | 에폭 14 |  반복 321 / 351 | 시간 14[s] | 손실 0.05
# | 에폭 14 |  반복 341 / 351 | 시간 15[s] | 손실 0.05
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 95.320%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 15 |  반복 21 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 15 |  반복 41 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 15 |  반복 61 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 15 |  반복 81 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 15 |  반복 101 / 351 | 시간 4[s] | 손실 0.04
# | 에폭 15 |  반복 121 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 15 |  반복 141 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 15 |  반복 161 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 15 |  반복 181 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 15 |  반복 201 / 351 | 시간 10[s] | 손실 0.04
# | 에폭 15 |  반복 221 / 351 | 시간 11[s] | 손실 0.04
# | 에폭 15 |  반복 241 / 351 | 시간 12[s] | 손실 0.03
# | 에폭 15 |  반복 261 / 351 | 시간 13[s] | 손실 0.05
# | 에폭 15 |  반복 281 / 351 | 시간 14[s] | 손실 0.06
# | 에폭 15 |  반복 301 / 351 | 시간 15[s] | 손실 0.05
# | 에폭 15 |  반복 321 / 351 | 시간 16[s] | 손실 0.04
# | 에폭 15 |  반복 341 / 351 | 시간 17[s] | 손실 0.04
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 94.620%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.04
# | 에폭 16 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 16 |  반복 61 / 351 | 시간 2[s] | 손실 0.04
# | 에폭 16 |  반복 81 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 16 |  반복 101 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 16 |  반복 121 / 351 | 시간 4[s] | 손실 0.04
# | 에폭 16 |  반복 141 / 351 | 시간 5[s] | 손실 0.04
# | 에폭 16 |  반복 161 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 16 |  반복 181 / 351 | 시간 7[s] | 손실 0.04
# | 에폭 16 |  반복 201 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 16 |  반복 221 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 16 |  반복 241 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 16 |  반복 261 / 351 | 시간 10[s] | 손실 0.03
# | 에폭 16 |  반복 281 / 351 | 시간 11[s] | 손실 0.04
# | 에폭 16 |  반복 301 / 351 | 시간 13[s] | 손실 0.04
# | 에폭 16 |  반복 321 / 351 | 시간 14[s] | 손실 0.04
# | 에폭 16 |  반복 341 / 351 | 시간 15[s] | 손실 0.04
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 96.200%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.03
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 17 |  반복 81 / 351 | 시간 3[s] | 손실 0.03
# | 에폭 17 |  반복 101 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 17 |  반복 121 / 351 | 시간 5[s] | 손실 0.02
# | 에폭 17 |  반복 141 / 351 | 시간 5[s] | 손실 0.02
# | 에폭 17 |  반복 161 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 17 |  반복 181 / 351 | 시간 7[s] | 손실 0.03
# | 에폭 17 |  반복 201 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 17 |  반복 221 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 17 |  반복 241 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 17 |  반복 261 / 351 | 시간 10[s] | 손실 0.03
# | 에폭 17 |  반복 281 / 351 | 시간 11[s] | 손실 0.04
# | 에폭 17 |  반복 301 / 351 | 시간 12[s] | 손실 0.04
# | 에폭 17 |  반복 321 / 351 | 시간 14[s] | 손실 0.04
# | 에폭 17 |  반복 341 / 351 | 시간 15[s] | 손실 0.05
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 92.700%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.06
# | 에폭 18 |  반복 41 / 351 | 시간 1[s] | 손실 0.06
# | 에폭 18 |  반복 61 / 351 | 시간 2[s] | 손실 0.05
# | 에폭 18 |  반복 81 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 18 |  반복 101 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 18 |  반복 121 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 18 |  반복 141 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 18 |  반복 161 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 18 |  반복 181 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 18 |  반복 201 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 18 |  반복 221 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 18 |  반복 241 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 18 |  반복 261 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 18 |  반복 281 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 18 |  반복 301 / 351 | 시간 10[s] | 손실 0.02
# | 에폭 18 |  반복 321 / 351 | 시간 11[s] | 손실 0.03
# | 에폭 18 |  반복 341 / 351 | 시간 11[s] | 손실 0.02
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 97.940%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 19 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 19 |  반복 81 / 351 | 시간 2[s] | 손실 0.02
# | 에폭 19 |  반복 101 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 19 |  반복 121 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 19 |  반복 141 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 19 |  반복 161 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 19 |  반복 181 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 19 |  반복 201 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 19 |  반복 221 / 351 | 시간 6[s] | 손실 0.04
# | 에폭 19 |  반복 241 / 351 | 시간 8[s] | 손실 0.04
# | 에폭 19 |  반복 261 / 351 | 시간 8[s] | 손실 0.03
# | 에폭 19 |  반복 281 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 19 |  반복 301 / 351 | 시간 10[s] | 손실 0.03
# | 에폭 19 |  반복 321 / 351 | 시간 10[s] | 손실 0.03
# | 에폭 19 |  반복 341 / 351 | 시간 11[s] | 손실 0.03
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 93.780%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.05
# | 에폭 20 |  반복 41 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.04
# | 에폭 20 |  반복 81 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 20 |  반복 101 / 351 | 시간 3[s] | 손실 0.04
# | 에폭 20 |  반복 121 / 351 | 시간 3[s] | 손실 0.05
# | 에폭 20 |  반복 141 / 351 | 시간 4[s] | 손실 0.04
# | 에폭 20 |  반복 161 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 20 |  반복 181 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 20 |  반복 201 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 20 |  반복 221 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 20 |  반복 241 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 20 |  반복 261 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 20 |  반복 281 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 20 |  반복 301 / 351 | 시간 9[s] | 손실 0.02
# | 에폭 20 |  반복 321 / 351 | 시간 10[s] | 손실 0.02
# | 에폭 20 |  반복 341 / 351 | 시간 10[s] | 손실 0.02
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 97.120%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 21 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 21 |  반복 81 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 21 |  반복 101 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 21 |  반복 121 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 21 |  반복 141 / 351 | 시간 5[s] | 손실 0.02
# | 에폭 21 |  반복 161 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 21 |  반복 181 / 351 | 시간 6[s] | 손실 0.02
# | 에폭 21 |  반복 201 / 351 | 시간 8[s] | 손실 0.02
# | 에폭 21 |  반복 221 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 21 |  반복 241 / 351 | 시간 10[s] | 손실 0.04
# | 에폭 21 |  반복 261 / 351 | 시간 10[s] | 손실 0.04
# | 에폭 21 |  반복 281 / 351 | 시간 11[s] | 손실 0.05
# | 에폭 21 |  반복 301 / 351 | 시간 11[s] | 손실 0.04
# | 에폭 21 |  반복 321 / 351 | 시간 12[s] | 손실 0.04
# | 에폭 21 |  반복 341 / 351 | 시간 13[s] | 손실 0.02
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 97.400%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.02
# | 에폭 22 |  반복 81 / 351 | 시간 2[s] | 손실 0.02
# | 에폭 22 |  반복 101 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 22 |  반복 121 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 22 |  반복 141 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 22 |  반복 161 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 22 |  반복 181 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 22 |  반복 201 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 22 |  반복 221 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 22 |  반복 241 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 22 |  반복 261 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 22 |  반복 281 / 351 | 시간 9[s] | 손실 0.01
# | 에폭 22 |  반복 301 / 351 | 시간 9[s] | 손실 0.01
# | 에폭 22 |  반복 321 / 351 | 시간 10[s] | 손실 0.01
# | 에폭 22 |  반복 341 / 351 | 시간 11[s] | 손실 0.01
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 98.560%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 23 |  반복 61 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 23 |  반복 81 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 23 |  반복 101 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 23 |  반복 121 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 23 |  반복 141 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 23 |  반복 161 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 23 |  반복 181 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 23 |  반복 201 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 23 |  반복 221 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 23 |  반복 241 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 23 |  반복 261 / 351 | 시간 8[s] | 손실 0.05
# | 에폭 23 |  반복 281 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 23 |  반복 301 / 351 | 시간 9[s] | 손실 0.05
# | 에폭 23 |  반복 321 / 351 | 시간 10[s] | 손실 0.04
# | 에폭 23 |  반복 341 / 351 | 시간 10[s] | 손실 0.04
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☒ 854
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 94.100%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.03
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.03
# | 에폭 24 |  반복 61 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 24 |  반복 81 / 351 | 시간 2[s] | 손실 0.03
# | 에폭 24 |  반복 101 / 351 | 시간 3[s] | 손실 0.02
# | 에폭 24 |  반복 121 / 351 | 시간 4[s] | 손실 0.02
# | 에폭 24 |  반복 141 / 351 | 시간 4[s] | 손실 0.03
# | 에폭 24 |  반복 161 / 351 | 시간 5[s] | 손실 0.03
# | 에폭 24 |  반복 181 / 351 | 시간 6[s] | 손실 0.03
# | 에폭 24 |  반복 201 / 351 | 시간 7[s] | 손실 0.02
# | 에폭 24 |  반복 221 / 351 | 시간 8[s] | 손실 0.04
# | 에폭 24 |  반복 241 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 24 |  반복 261 / 351 | 시간 9[s] | 손실 0.03
# | 에폭 24 |  반복 281 / 351 | 시간 10[s] | 손실 0.02
# | 에폭 24 |  반복 301 / 351 | 시간 11[s] | 손실 0.02
# | 에폭 24 |  반복 321 / 351 | 시간 11[s] | 손실 0.02
# | 에폭 24 |  반복 341 / 351 | 시간 12[s] | 손실 0.02
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 97.960%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.02
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 25 |  반복 41 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.01
# | 에폭 25 |  반복 81 / 351 | 시간 2[s] | 손실 0.01
# | 에폭 25 |  반복 101 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 25 |  반복 121 / 351 | 시간 3[s] | 손실 0.01
# | 에폭 25 |  반복 141 / 351 | 시간 4[s] | 손실 0.01
# | 에폭 25 |  반복 161 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 25 |  반복 181 / 351 | 시간 5[s] | 손실 0.01
# | 에폭 25 |  반복 201 / 351 | 시간 6[s] | 손실 0.01
# | 에폭 25 |  반복 221 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 25 |  반복 241 / 351 | 시간 7[s] | 손실 0.01
# | 에폭 25 |  반복 261 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 25 |  반복 281 / 351 | 시간 8[s] | 손실 0.01
# | 에폭 25 |  반복 301 / 351 | 시간 9[s] | 손실 0.01
# | 에폭 25 |  반복 321 / 351 | 시간 10[s] | 손실 0.02
# | 에폭 25 |  반복 341 / 351 | 시간 11[s] | 손실 0.02
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1149
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☑ 1427
# ---
# Q 26+838
# T 864
# ☑ 864
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 97.120%
