# %% [markdown]
# ## 게이트 추가된

# %%
from colorsys import hsv_to_rgb

import numpy as np
import matplotlib.pyplot as plt

from Batch_Normalization_lab import batch_size

N = 2  # 미니배치 크기
H = 3  # 은닉 상태 벡터의 차원 수
T = 20  # 시계열 데이터의 길이

dh = np.ones((N, H))
np.random.seed(3)
Wh = np.random.randn(H, H) * 0.5

norm_list = []
for t in range(T):
    dh = np.dot(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)


print(norm_list)

# 그래프 그리기
plt.plot(np.arange(len(norm_list)), norm_list)
plt.xticks([0, 4, 9, 14, 19], [1, 5, 10, 15, 20])
plt.xlabel('time step')
plt.ylabel('norm')
plt.show()
# Out:
# [1.2342034047289652, 0.8339262435402592, 0.5979099219216478, 0.3924742082554759, 0.25252426453184545, 0.16017442237957719, 0.10106299614538984, 0.06358148956166684, 0.039950839098332, 0.025086887541098325, 0.015748611904532892, 0.009884999125204758, 0.006204151282595104, 0.003893806551809953, 0.002443767399386287, 0.0015337065005571367, 0.0009625497320203268, 0.0006040924319556743, 0.00037912574706291117, 0.00023793756048323344]

# %%
import numpy as np

dW1 = np.random.rand(3, 3) * 10
dW2 = np.random.rand(3, 3) * 10
grads = [dW1, dW2]
max_norm = 5.0

def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate


print('before:', dW1.flatten())
clip_grads(grads, max_norm)
print('after:', dW1.flatten())
# Out:
# before: [6.49144048 2.78487283 6.76254902 5.90862817 0.23981882 5.58854088
#  2.59252447 4.15101197 2.83525082]
# after: [1.49503731 0.64138134 1.55747605 1.36081038 0.05523244 1.28709139
#  0.59708178 0.95601551 0.65298384]

# %%
class LSTM:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None

    def forward(self, x, h_prev, c_prev):
        Wx, Wh, b = self.params
        N, H = h_prev.shape

        A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b

        f = A[:, :H]
        g = A[:, H:2*H]
        i = A[:, 2*H:3*H]
        o = A[:, 3*H:]

        f = sigmoid(f)
        g = np.tanh(g)
        i = sigmoid(i)
        o = sigmoid(o)

        c_next = f * c_prev + g * i
        h_next = o * np.tanh(c_next)

        self.cache = (x, h_prev, c_prev, i, f, g, o, c_next)
        return h_next, c_next

# %%
class TimeLSTM:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None

        self.h, self.c = None, None
        self.dh = None
        self.stateful = stateful

    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        H = Wh.shape[0]

        self.layers = []
        hs = np.empty((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
        if not self.stateful or self.c is None:
            self.c = np.zeros((N, H), dtype='f')

        for t in range(T):
            layer = LSTM(*self.params)
            self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
            hs[:, t, :] = self.h

            self.layers.append(layer)
        return hs

    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D = Wx.shape[0]

        dxs = np.empty((N, T, D), dtype='f')
        dh, dc = 0, 0

        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
            dxs[:, t, :] = dx
            for i, grad in enumerate(layer.grads):
                grads[i] += grad

        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh
        return dxs

    def set_state(self, h, c=None):
        self.h, self.c = h, c

    def reset_state(self):
        self.h, self.c = None, None

# %%
import sys
sys.path.append('..')
from common.time_layers import  *
import pickle

class Rnnlm:
    def __init__(self, vocab_size=1000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs


    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.lstm_layer.reset_state()

    def save_params(self, file_name='params.pkl'):
        with open(file_name, 'wb') as f:
            pickle.dump(self.params, f)

    def load_params(self, file_name='params.pkl'):
        with open(file_name, 'rb') as f:
            self.params = pickle.load(f)

# %%
import sys
sys.path.append('..' )
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
#from rnnlm import Rnnlm

# 하이퍼파라미터 설정
batch_size = 20
wordvec_size = 100
hidden_size = 100
time_size = 35
lr = 20.0
max_epoch = 4
max_grad = 0.25

corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim=(0,500))

model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('테스트 퍼플렉서티: ', ppl_test)

model.save_params()
# Out:
# Downloading ptb.test.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9999.69
# | 에폭 1 |  반복 21 / 1327 | 시간 3[s] | 퍼플렉서티 2965.95
# | 에폭 1 |  반복 41 / 1327 | 시간 6[s] | 퍼플렉서티 1248.70
# | 에폭 1 |  반복 61 / 1327 | 시간 9[s] | 퍼플렉서티 952.89
# | 에폭 1 |  반복 81 / 1327 | 시간 11[s] | 퍼플렉서티 790.06
# | 에폭 1 |  반복 101 / 1327 | 시간 14[s] | 퍼플렉서티 662.58
# | 에폭 1 |  반복 121 / 1327 | 시간 16[s] | 퍼플렉서티 643.41
# | 에폭 1 |  반복 141 / 1327 | 시간 19[s] | 퍼플렉서티 609.01
# | 에폭 1 |  반복 161 / 1327 | 시간 22[s] | 퍼플렉서티 567.93
# | 에폭 1 |  반복 181 / 1327 | 시간 25[s] | 퍼플렉서티 585.87
# | 에폭 1 |  반복 201 / 1327 | 시간 28[s] | 퍼플렉서티 505.99
# | 에폭 1 |  반복 221 / 1327 | 시간 30[s] | 퍼플렉서티 494.55
# | 에폭 1 |  반복 241 / 1327 | 시간 34[s] | 퍼플렉서티 448.11
# | 에폭 1 |  반복 261 / 1327 | 시간 37[s] | 퍼플렉서티 477.23
# | 에폭 1 |  반복 281 / 1327 | 시간 39[s] | 퍼플렉서티 467.23
# | 에폭 1 |  반복 301 / 1327 | 시간 42[s] | 퍼플렉서티 391.85
# | 에폭 1 |  반복 321 / 1327 | 시간 44[s] | 퍼플렉서티 340.44
# | 에폭 1 |  반복 341 / 1327 | 시간 47[s] | 퍼플렉서티 410.33
# | 에폭 1 |  반복 361 / 1327 | 시간 50[s] | 퍼플렉서티 408.47
# | 에폭 1 |  반복 381 / 1327 | 시간 52[s] | 퍼플렉서티 342.82
# | 에폭 1 |  반복 401 / 1327 | 시간 55[s] | 퍼플렉서티 357.74
# | 에폭 1 |  반복 421 / 1327 | 시간 58[s] | 퍼플렉서티 349.49
# | 에폭 1 |  반복 441 / 1327 | 시간 60[s] | 퍼플렉서티 339.12
# | 에폭 1 |  반복 461 / 1327 | 시간 63[s] | 퍼플렉서티 331.20
# | 에폭 1 |  반복 481 / 1327 | 시간 66[s] | 퍼플렉서티 308.45
# | 에폭 1 |  반복 501 / 1327 | 시간 69[s] | 퍼플렉서티 314.57
# | 에폭 1 |  반복 521 / 1327 | 시간 71[s] | 퍼플렉서티 308.60
# | 에폭 1 |  반복 541 / 1327 | 시간 74[s] | 퍼플렉서티 317.14
# | 에폭 1 |  반복 561 / 1327 | 시간 76[s] | 퍼플렉서티 286.20
# | 에폭 1 |  반복 581 / 1327 | 시간 79[s] | 퍼플렉서티 261.16
# | 에폭 1 |  반복 601 / 1327 | 시간 82[s] | 퍼플렉서티 340.46
# | 에폭 1 |  반복 621 / 1327 | 시간 85[s] | 퍼플렉서티 312.00
# | 에폭 1 |  반복 641 / 1327 | 시간 88[s] | 퍼플렉서티 284.45
# | 에폭 1 |  반복 661 / 1327 | 시간 91[s] | 퍼플렉서티 267.89
# | 에폭 1 |  반복 681 / 1327 | 시간 94[s] | 퍼플렉서티 230.71
# | 에폭 1 |  반복 701 / 1327 | 시간 97[s] | 퍼플렉서티 250.96
# | 에폭 1 |  반복 721 / 1327 | 시간 100[s] | 퍼플렉서티 263.17
# | 에폭 1 |  반복 741 / 1327 | 시간 102[s] | 퍼플렉서티 223.13
# | 에폭 1 |  반복 761 / 1327 | 시간 105[s] | 퍼플렉서티 237.49
# | 에폭 1 |  반복 781 / 1327 | 시간 108[s] | 퍼플렉서티 219.87
# | 에폭 1 |  반복 801 / 1327 | 시간 111[s] | 퍼플렉서티 241.53
# | 에폭 1 |  반복 821 / 1327 | 시간 113[s] | 퍼플렉서티 224.38
# | 에폭 1 |  반복 841 / 1327 | 시간 116[s] | 퍼플렉서티 229.04
# | 에폭 1 |  반복 861 / 1327 | 시간 118[s] | 퍼플렉서티 220.81
# | 에폭 1 |  반복 881 / 1327 | 시간 121[s] | 퍼플렉서티 206.78
# | 에폭 1 |  반복 901 / 1327 | 시간 124[s] | 퍼플렉서티 254.29
# | 에폭 1 |  반복 921 / 1327 | 시간 127[s] | 퍼플렉서티 230.43
# | 에폭 1 |  반복 941 / 1327 | 시간 130[s] | 퍼플렉서티 230.73
# | 에폭 1 |  반복 961 / 1327 | 시간 132[s] | 퍼플렉서티 245.66
# | 에폭 1 |  반복 981 / 1327 | 시간 135[s] | 퍼플렉서티 229.98
# | 에폭 1 |  반복 1001 / 1327 | 시간 138[s] | 퍼플렉서티 192.19
# | 에폭 1 |  반복 1021 / 1327 | 시간 140[s] | 퍼플렉서티 226.10
# | 에폭 1 |  반복 1041 / 1327 | 시간 143[s] | 퍼플렉서티 207.86
# | 에폭 1 |  반복 1061 / 1327 | 시간 146[s] | 퍼플렉서티 195.85
# | 에폭 1 |  반복 1081 / 1327 | 시간 149[s] | 퍼플렉서티 168.22
# | 에폭 1 |  반복 1101 / 1327 | 시간 152[s] | 퍼플렉서티 194.38
# | 에폭 1 |  반복 1121 / 1327 | 시간 155[s] | 퍼플렉서티 229.42
# | 에폭 1 |  반복 1141 / 1327 | 시간 158[s] | 퍼플렉서티 207.55
# | 에폭 1 |  반복 1161 / 1327 | 시간 161[s] | 퍼플렉서티 198.38
# | 에폭 1 |  반복 1181 / 1327 | 시간 163[s] | 퍼플렉서티 190.83
# | 에폭 1 |  반복 1201 / 1327 | 시간 166[s] | 퍼플렉서티 162.13
# | 에폭 1 |  반복 1221 / 1327 | 시간 169[s] | 퍼플렉서티 159.52
# | 에폭 1 |  반복 1241 / 1327 | 시간 171[s] | 퍼플렉서티 187.47
# | 에폭 1 |  반복 1261 / 1327 | 시간 174[s] | 퍼플렉서티 172.37
# | 에폭 1 |  반복 1281 / 1327 | 시간 177[s] | 퍼플렉서티 177.76
# | 에폭 1 |  반복 1301 / 1327 | 시간 179[s] | 퍼플렉서티 222.17
# | 에폭 1 |  반복 1321 / 1327 | 시간 182[s] | 퍼플렉서티 211.10
# | 에폭 2 |  반복 1 / 1327 | 시간 184[s] | 퍼플렉서티 223.05
# | 에폭 2 |  반복 21 / 1327 | 시간 186[s] | 퍼플렉서티 204.71
# | 에폭 2 |  반복 41 / 1327 | 시간 189[s] | 퍼플렉서티 189.96
# | 에폭 2 |  반복 61 / 1327 | 시간 192[s] | 퍼플렉서티 175.89
# | 에폭 2 |  반복 81 / 1327 | 시간 195[s] | 퍼플렉서티 159.22
# | 에폭 2 |  반복 101 / 1327 | 시간 198[s] | 퍼플렉서티 151.05
# | 에폭 2 |  반복 121 / 1327 | 시간 201[s] | 퍼플렉서티 159.42
# | 에폭 2 |  반복 141 / 1327 | 시간 204[s] | 퍼플렉서티 177.92
# | 에폭 2 |  반복 161 / 1327 | 시간 207[s] | 퍼플렉서티 193.22
# | 에폭 2 |  반복 181 / 1327 | 시간 210[s] | 퍼플렉서티 203.60
# | 에폭 2 |  반복 201 / 1327 | 시간 214[s] | 퍼플렉서티 184.64
# | 에폭 2 |  반복 221 / 1327 | 시간 217[s] | 퍼플렉서티 182.98
# | 에폭 2 |  반복 241 / 1327 | 시간 220[s] | 퍼플렉서티 176.16
# | 에폭 2 |  반복 261 / 1327 | 시간 223[s] | 퍼플렉서티 184.71
# | 에폭 2 |  반복 281 / 1327 | 시간 226[s] | 퍼플렉서티 185.86
# | 에폭 2 |  반복 301 / 1327 | 시간 229[s] | 퍼플렉서티 166.38
# | 에폭 2 |  반복 321 / 1327 | 시간 232[s] | 퍼플렉서티 137.61
# | 에폭 2 |  반복 341 / 1327 | 시간 235[s] | 퍼플렉서티 171.03
# | 에폭 2 |  반복 361 / 1327 | 시간 238[s] | 퍼플렉서티 198.59
# | 에폭 2 |  반복 381 / 1327 | 시간 241[s] | 퍼플렉서티 154.46
# | 에폭 2 |  반복 401 / 1327 | 시간 245[s] | 퍼플렉서티 168.04
# | 에폭 2 |  반복 421 / 1327 | 시간 248[s] | 퍼플렉서티 154.64
# | 에폭 2 |  반복 441 / 1327 | 시간 251[s] | 퍼플렉서티 163.05
# | 에폭 2 |  반복 461 / 1327 | 시간 254[s] | 퍼플렉서티 157.29
# | 에폭 2 |  반복 481 / 1327 | 시간 257[s] | 퍼플렉서티 155.77
# | 에폭 2 |  반복 501 / 1327 | 시간 260[s] | 퍼플렉서티 169.05
# | 에폭 2 |  반복 521 / 1327 | 시간 263[s] | 퍼플렉서티 173.24
# | 에폭 2 |  반복 541 / 1327 | 시간 266[s] | 퍼플렉서티 173.88
# | 에폭 2 |  반복 561 / 1327 | 시간 270[s] | 퍼플렉서티 155.01
# | 에폭 2 |  반복 581 / 1327 | 시간 275[s] | 퍼플렉서티 137.93
# | 에폭 2 |  반복 601 / 1327 | 시간 278[s] | 퍼플렉서티 189.06
# | 에폭 2 |  반복 621 / 1327 | 시간 281[s] | 퍼플렉서티 181.05
# | 에폭 2 |  반복 641 / 1327 | 시간 284[s] | 퍼플렉서티 164.43
# | 에폭 2 |  반복 661 / 1327 | 시간 287[s] | 퍼플렉서티 154.54
# | 에폭 2 |  반복 681 / 1327 | 시간 292[s] | 퍼플렉서티 129.35
# | 에폭 2 |  반복 701 / 1327 | 시간 295[s] | 퍼플렉서티 150.79
# | 에폭 2 |  반복 721 / 1327 | 시간 300[s] | 퍼플렉서티 159.46
# | 에폭 2 |  반복 741 / 1327 | 시간 304[s] | 퍼플렉서티 132.21
# | 에폭 2 |  반복 761 / 1327 | 시간 307[s] | 퍼플렉서티 128.88
# | 에폭 2 |  반복 781 / 1327 | 시간 311[s] | 퍼플렉서티 134.53
# | 에폭 2 |  반복 801 / 1327 | 시간 316[s] | 퍼플렉서티 147.31
# | 에폭 2 |  반복 821 / 1327 | 시간 322[s] | 퍼플렉서티 143.63
# | 에폭 2 |  반복 841 / 1327 | 시간 328[s] | 퍼플렉서티 144.12
# | 에폭 2 |  반복 861 / 1327 | 시간 332[s] | 퍼플렉서티 144.09
# | 에폭 2 |  반복 881 / 1327 | 시간 336[s] | 퍼플렉서티 130.36
# | 에폭 2 |  반복 901 / 1327 | 시간 339[s] | 퍼플렉서티 166.93
# | 에폭 2 |  반복 921 / 1327 | 시간 342[s] | 퍼플렉서티 147.18
# | 에폭 2 |  반복 941 / 1327 | 시간 346[s] | 퍼플렉서티 151.75
# | 에폭 2 |  반복 961 / 1327 | 시간 353[s] | 퍼플렉서티 163.87
# | 에폭 2 |  반복 981 / 1327 | 시간 358[s] | 퍼플렉서티 155.11
# | 에폭 2 |  반복 1001 / 1327 | 시간 365[s] | 퍼플렉서티 131.21
# | 에폭 2 |  반복 1021 / 1327 | 시간 368[s] | 퍼플렉서티 156.24
# | 에폭 2 |  반복 1041 / 1327 | 시간 374[s] | 퍼플렉서티 144.62
# | 에폭 2 |  반복 1061 / 1327 | 시간 379[s] | 퍼플렉서티 128.16
# | 에폭 2 |  반복 1081 / 1327 | 시간 384[s] | 퍼플렉서티 110.50
# | 에폭 2 |  반복 1101 / 1327 | 시간 388[s] | 퍼플렉서티 119.65
# | 에폭 2 |  반복 1121 / 1327 | 시간 393[s] | 퍼플렉서티 154.13
# | 에폭 2 |  반복 1141 / 1327 | 시간 397[s] | 퍼플렉서티 141.53
# | 에폭 2 |  반복 1161 / 1327 | 시간 400[s] | 퍼플렉서티 132.26
# | 에폭 2 |  반복 1181 / 1327 | 시간 404[s] | 퍼플렉서티 133.54
# | 에폭 2 |  반복 1201 / 1327 | 시간 408[s] | 퍼플렉서티 112.20
# | 에폭 2 |  반복 1221 / 1327 | 시간 412[s] | 퍼플렉서티 109.59
# | 에폭 2 |  반복 1241 / 1327 | 시간 418[s] | 퍼플렉서티 130.47
# | 에폭 2 |  반복 1261 / 1327 | 시간 422[s] | 퍼플렉서티 123.89
# | 에폭 2 |  반복 1281 / 1327 | 시간 426[s] | 퍼플렉서티 123.07
# | 에폭 2 |  반복 1301 / 1327 | 시간 430[s] | 퍼플렉서티 158.17
# | 에폭 2 |  반복 1321 / 1327 | 시간 435[s] | 퍼플렉서티 152.62
# | 에폭 3 |  반복 1 / 1327 | 시간 436[s] | 퍼플렉서티 162.49
# | 에폭 3 |  반복 21 / 1327 | 시간 441[s] | 퍼플렉서티 144.03
# | 에폭 3 |  반복 41 / 1327 | 시간 446[s] | 퍼플렉서티 136.62
# | 에폭 3 |  반복 61 / 1327 | 시간 449[s] | 퍼플렉서티 126.93
# | 에폭 3 |  반복 81 / 1327 | 시간 454[s] | 퍼플렉서티 118.27
# | 에폭 3 |  반복 101 / 1327 | 시간 458[s] | 퍼플렉서티 105.39
# | 에폭 3 |  반복 121 / 1327 | 시간 463[s] | 퍼플렉서티 116.13
# | 에폭 3 |  반복 141 / 1327 | 시간 471[s] | 퍼플렉서티 126.63
# | 에폭 3 |  반복 161 / 1327 | 시간 475[s] | 퍼플렉서티 141.82
# | 에폭 3 |  반복 181 / 1327 | 시간 482[s] | 퍼플렉서티 151.78
# | 에폭 3 |  반복 201 / 1327 | 시간 486[s] | 퍼플렉서티 140.89
# | 에폭 3 |  반복 221 / 1327 | 시간 490[s] | 퍼플렉서티 141.12
# | 에폭 3 |  반복 241 / 1327 | 시간 494[s] | 퍼플렉서티 134.96
# | 에폭 3 |  반복 261 / 1327 | 시간 500[s] | 퍼플렉서티 139.42
# | 에폭 3 |  반복 281 / 1327 | 시간 505[s] | 퍼플렉서티 141.41
# | 에폭 3 |  반복 301 / 1327 | 시간 508[s] | 퍼플렉서티 122.24
# | 에폭 3 |  반복 321 / 1327 | 시간 511[s] | 퍼플렉서티 101.79
# | 에폭 3 |  반복 341 / 1327 | 시간 515[s] | 퍼플렉서티 124.77
# | 에폭 3 |  반복 361 / 1327 | 시간 518[s] | 퍼플렉서티 153.04
# | 에폭 3 |  반복 381 / 1327 | 시간 521[s] | 퍼플렉서티 115.74
# | 에폭 3 |  반복 401 / 1327 | 시간 524[s] | 퍼플렉서티 130.38
# | 에폭 3 |  반복 421 / 1327 | 시간 534[s] | 퍼플렉서티 114.41
# | 에폭 3 |  반복 441 / 1327 | 시간 538[s] | 퍼플렉서티 124.01
# | 에폭 3 |  반복 461 / 1327 | 시간 541[s] | 퍼플렉서티 118.95
# | 에폭 3 |  반복 481 / 1327 | 시간 545[s] | 퍼플렉서티 120.29
# | 에폭 3 |  반복 501 / 1327 | 시간 548[s] | 퍼플렉서티 128.96
# | 에폭 3 |  반복 521 / 1327 | 시간 551[s] | 퍼플렉서티 137.64
# | 에폭 3 |  반복 541 / 1327 | 시간 554[s] | 퍼플렉서티 136.17
# | 에폭 3 |  반복 561 / 1327 | 시간 560[s] | 퍼플렉서티 118.60
# | 에폭 3 |  반복 581 / 1327 | 시간 563[s] | 퍼플렉서티 105.53
# | 에폭 3 |  반복 601 / 1327 | 시간 566[s] | 퍼플렉서티 150.16
# | 에폭 3 |  반복 621 / 1327 | 시간 569[s] | 퍼플렉서티 142.40
# | 에폭 3 |  반복 641 / 1327 | 시간 576[s] | 퍼플렉서티 129.62
# | 에폭 3 |  반복 661 / 1327 | 시간 584[s] | 퍼플렉서티 120.87
# | 에폭 3 |  반복 681 / 1327 | 시간 587[s] | 퍼플렉서티 100.11
# | 에폭 3 |  반복 701 / 1327 | 시간 593[s] | 퍼플렉서티 118.95
# | 에폭 3 |  반복 721 / 1327 | 시간 602[s] | 퍼플렉서티 127.55
# | 에폭 3 |  반복 741 / 1327 | 시간 609[s] | 퍼플렉서티 107.43
# | 에폭 3 |  반복 761 / 1327 | 시간 613[s] | 퍼플렉서티 102.70
# | 에폭 3 |  반복 781 / 1327 | 시간 618[s] | 퍼플렉서티 103.58
# | 에폭 3 |  반복 801 / 1327 | 시간 624[s] | 퍼플렉서티 116.13
# | 에폭 3 |  반복 821 / 1327 | 시간 629[s] | 퍼플렉서티 117.91
# | 에폭 3 |  반복 841 / 1327 | 시간 637[s] | 퍼플렉서티 114.42
# | 에폭 3 |  반복 861 / 1327 | 시간 644[s] | 퍼플렉서티 119.00
# | 에폭 3 |  반복 881 / 1327 | 시간 649[s] | 퍼플렉서티 107.04
# | 에폭 3 |  반복 901 / 1327 | 시간 656[s] | 퍼플렉서티 132.33
# | 에폭 3 |  반복 921 / 1327 | 시간 661[s] | 퍼플렉서티 118.38
# | 에폭 3 |  반복 941 / 1327 | 시간 665[s] | 퍼플렉서티 126.27
# | 에폭 3 |  반복 961 / 1327 | 시간 670[s] | 퍼플렉서티 131.99
# | 에폭 3 |  반복 981 / 1327 | 시간 677[s] | 퍼플렉서티 124.78
# | 에폭 3 |  반복 1001 / 1327 | 시간 684[s] | 퍼플렉서티 109.87
# | 에폭 3 |  반복 1021 / 1327 | 시간 687[s] | 퍼플렉서티 129.35
# | 에폭 3 |  반복 1041 / 1327 | 시간 691[s] | 퍼플렉서티 119.69
# | 에폭 3 |  반복 1061 / 1327 | 시간 698[s] | 퍼플렉서티 103.27
# | 에폭 3 |  반복 1081 / 1327 | 시간 705[s] | 퍼플렉서티 89.48
# | 에폭 3 |  반복 1101 / 1327 | 시간 708[s] | 퍼플렉서티 95.77
# | 에폭 3 |  반복 1121 / 1327 | 시간 711[s] | 퍼플렉서티 123.09
# | 에폭 3 |  반복 1141 / 1327 | 시간 714[s] | 퍼플렉서티 115.41
# | 에폭 3 |  반복 1161 / 1327 | 시간 718[s] | 퍼플렉서티 106.95
# | 에폭 3 |  반복 1181 / 1327 | 시간 722[s] | 퍼플렉서티 111.56
# | 에폭 3 |  반복 1201 / 1327 | 시간 726[s] | 퍼플렉서티 95.08
# | 에폭 3 |  반복 1221 / 1327 | 시간 730[s] | 퍼플렉서티 89.63
# | 에폭 3 |  반복 1241 / 1327 | 시간 734[s] | 퍼플렉서티 106.22
# | 에폭 3 |  반복 1261 / 1327 | 시간 738[s] | 퍼플렉서티 105.20
# | 에폭 3 |  반복 1281 / 1327 | 시간 742[s] | 퍼플렉서티 100.90
# | 에폭 3 |  반복 1301 / 1327 | 시간 747[s] | 퍼플렉서티 129.31
# | 에폭 3 |  반복 1321 / 1327 | 시간 757[s] | 퍼플렉서티 126.84
# | 에폭 4 |  반복 1 / 1327 | 시간 759[s] | 퍼플렉서티 135.83
# | 에폭 4 |  반복 21 / 1327 | 시간 764[s] | 퍼플렉서티 122.51
# | 에폭 4 |  반복 41 / 1327 | 시간 772[s] | 퍼플렉서티 107.01
# | 에폭 4 |  반복 61 / 1327 | 시간 778[s] | 퍼플렉서티 108.55
# | 에폭 4 |  반복 81 / 1327 | 시간 782[s] | 퍼플렉서티 97.63
# | 에폭 4 |  반복 101 / 1327 | 시간 786[s] | 퍼플렉서티 87.07
# | 에폭 4 |  반복 121 / 1327 | 시간 791[s] | 퍼플렉서티 97.32
# | 에폭 4 |  반복 141 / 1327 | 시간 794[s] | 퍼플렉서티 104.89
# | 에폭 4 |  반복 161 / 1327 | 시간 797[s] | 퍼플렉서티 117.64
# | 에폭 4 |  반복 181 / 1327 | 시간 801[s] | 퍼플렉서티 130.11
# | 에폭 4 |  반복 201 / 1327 | 시간 806[s] | 퍼플렉서티 119.78
# | 에폭 4 |  반복 221 / 1327 | 시간 809[s] | 퍼플렉서티 122.40
# | 에폭 4 |  반복 241 / 1327 | 시간 812[s] | 퍼플렉서티 115.08
# | 에폭 4 |  반복 261 / 1327 | 시간 815[s] | 퍼플렉서티 115.55
# | 에폭 4 |  반복 281 / 1327 | 시간 818[s] | 퍼플렉서티 121.69
# | 에폭 4 |  반복 301 / 1327 | 시간 821[s] | 퍼플렉서티 104.50
# | 에폭 4 |  반복 321 / 1327 | 시간 824[s] | 퍼플렉서티 84.57
# | 에폭 4 |  반복 341 / 1327 | 시간 827[s] | 퍼플렉서티 100.93
# | 에폭 4 |  반복 361 / 1327 | 시간 831[s] | 퍼플렉서티 129.82
# | 에폭 4 |  반복 381 / 1327 | 시간 835[s] | 퍼플렉서티 98.78
# | 에폭 4 |  반복 401 / 1327 | 시간 838[s] | 퍼플렉서티 111.52
# | 에폭 4 |  반복 421 / 1327 | 시간 841[s] | 퍼플렉서티 94.83
# | 에폭 4 |  반복 441 / 1327 | 시간 845[s] | 퍼플렉서티 104.25
# | 에폭 4 |  반복 461 / 1327 | 시간 848[s] | 퍼플렉서티 100.59
# | 에폭 4 |  반복 481 / 1327 | 시간 851[s] | 퍼플렉서티 104.54
# | 에폭 4 |  반복 501 / 1327 | 시간 854[s] | 퍼플렉서티 109.19
# | 에폭 4 |  반복 521 / 1327 | 시간 857[s] | 퍼플렉서티 117.66
# | 에폭 4 |  반복 541 / 1327 | 시간 861[s] | 퍼플렉서티 114.24
# | 에폭 4 |  반복 561 / 1327 | 시간 864[s] | 퍼플렉서티 103.46
# | 에폭 4 |  반복 581 / 1327 | 시간 867[s] | 퍼플렉서티 89.09
# | 에폭 4 |  반복 601 / 1327 | 시간 870[s] | 퍼플렉서티 129.08
# | 에폭 4 |  반복 621 / 1327 | 시간 874[s] | 퍼플렉서티 121.21
# | 에폭 4 |  반복 641 / 1327 | 시간 878[s] | 퍼플렉서티 110.99
# | 에폭 4 |  반복 661 / 1327 | 시간 881[s] | 퍼플렉서티 103.72
# | 에폭 4 |  반복 681 / 1327 | 시간 884[s] | 퍼플렉서티 85.55
# | 에폭 4 |  반복 701 / 1327 | 시간 887[s] | 퍼플렉서티 102.71
# | 에폭 4 |  반복 721 / 1327 | 시간 890[s] | 퍼플렉서티 109.53
# | 에폭 4 |  반복 741 / 1327 | 시간 893[s] | 퍼플렉서티 96.23
# | 에폭 4 |  반복 761 / 1327 | 시간 897[s] | 퍼플렉서티 89.94
# | 에폭 4 |  반복 781 / 1327 | 시간 901[s] | 퍼플렉서티 88.06
# | 에폭 4 |  반복 801 / 1327 | 시간 905[s] | 퍼플렉서티 99.82
# | 에폭 4 |  반복 821 / 1327 | 시간 909[s] | 퍼플렉서티 104.27
# | 에폭 4 |  반복 841 / 1327 | 시간 912[s] | 퍼플렉서티 99.59
# | 에폭 4 |  반복 861 / 1327 | 시간 917[s] | 퍼플렉서티 104.11
# | 에폭 4 |  반복 881 / 1327 | 시간 921[s] | 퍼플렉서티 92.96
# | 에폭 4 |  반복 901 / 1327 | 시간 925[s] | 퍼플렉서티 116.43
# | 에폭 4 |  반복 921 / 1327 | 시간 930[s] | 퍼플렉서티 103.81
# | 에폭 4 |  반복 941 / 1327 | 시간 937[s] | 퍼플렉서티 112.57
# | 에폭 4 |  반복 961 / 1327 | 시간 941[s] | 퍼플렉서티 113.38
# | 에폭 4 |  반복 981 / 1327 | 시간 945[s] | 퍼플렉서티 108.32
# | 에폭 4 |  반복 1001 / 1327 | 시간 948[s] | 퍼플렉서티 98.27
# | 에폭 4 |  반복 1021 / 1327 | 시간 953[s] | 퍼플렉서티 114.16
# | 에폭 4 |  반복 1041 / 1327 | 시간 957[s] | 퍼플렉서티 104.87
# | 에폭 4 |  반복 1061 / 1327 | 시간 964[s] | 퍼플렉서티 89.94
# | 에폭 4 |  반복 1081 / 1327 | 시간 970[s] | 퍼플렉서티 79.64
# | 에폭 4 |  반복 1101 / 1327 | 시간 977[s] | 퍼플렉서티 80.09
# | 에폭 4 |  반복 1121 / 1327 | 시간 983[s] | 퍼플렉서티 104.77
# | 에폭 4 |  반복 1141 / 1327 | 시간 988[s] | 퍼플렉서티 101.96
# | 에폭 4 |  반복 1161 / 1327 | 시간 994[s] | 퍼플렉서티 92.88
# | 에폭 4 |  반복 1181 / 1327 | 시간 998[s] | 퍼플렉서티 97.23
# | 에폭 4 |  반복 1201 / 1327 | 시간 1003[s] | 퍼플렉서티 84.73
# | 에폭 4 |  반복 1221 / 1327 | 시간 1007[s] | 퍼플렉서티 77.23
# | 에폭 4 |  반복 1241 / 1327 | 시간 1013[s] | 퍼플렉서티 92.46
# | 에폭 4 |  반복 1261 / 1327 | 시간 1017[s] | 퍼플렉서티 93.88
# | 에폭 4 |  반복 1281 / 1327 | 시간 1023[s] | 퍼플렉서티 90.15
# | 에폭 4 |  반복 1301 / 1327 | 시간 1030[s] | 퍼플렉서티 112.12
# | 에폭 4 |  반복 1321 / 1327 | 시간 1037[s] | 퍼플렉서티 110.85
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48152 (\N{HANGUL SYLLABLE BAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48373 (\N{HANGUL SYLLABLE BOG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54140 (\N{HANGUL SYLLABLE PEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54540 (\N{HANGUL SYLLABLE PEUL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47113 (\N{HANGUL SYLLABLE REG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/chohi/project/ai/DeepLearningDeepen/DeepLearningAdv/.venv/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54000 (\N{HANGUL SYLLABLE TI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 퍼플렉서티 평가 중 ...
# 234 / 235
# 테스트 퍼플렉서티:  135.54397447523272

# %% [markdown]
# ### 개선된 RNNLM 구현

# %%
import sys
sys.path.append('..')
from common.time_layers import  *
from common.np import *
from common.base_model import BaseModel

class Rnnlm(BaseModel):
    def __init__(self, vocab_size=1000, wordvec_size=650, hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # 가중치 공유
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.dropout_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.dropout_layers:
            layer.train_flg = train_flg
        for layer in self.lstm_layers:
            xs = layer.forward(xs)
        return xs


    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def rest_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
from common import config

from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from better_rnnlm import BetterRnnlm

batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
corpus_val, _, _ = ptb.load_data('val')

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size, time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('검증 퍼플렉서티: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)
# Out:
# Downloading ptb.valid.txt ...
# Done
# | 에폭 1 |  반복 1 / 1327 | 시간 1[s] | 퍼플렉서티 10000.54
# | 에폭 1 |  반복 21 / 1327 | 시간 25[s] | 퍼플렉서티 3975.32
# | 에폭 1 |  반복 41 / 1327 | 시간 48[s] | 퍼플렉서티 1867.06
# | 에폭 1 |  반복 61 / 1327 | 시간 72[s] | 퍼플렉서티 1265.59
# | 에폭 1 |  반복 81 / 1327 | 시간 94[s] | 퍼플렉서티 1010.71
# | 에폭 1 |  반복 101 / 1327 | 시간 119[s] | 퍼플렉서티 825.33
