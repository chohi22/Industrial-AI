# %%
print('Hello Python')
# Out:
# Hello Python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# !ls ./drive/MyDrive -la
# Out:
# total 1968
# -rw------- 1 root root 1594291 Jun 28  2024 'A100 서버 사용 메뉴얼(최종)_2024.pptx'
# drwx------ 2 root root    4096 Apr  4  2024 'Colab Notebooks'
# -rw------- 1 root root   76708 Apr 17  2024  langchain_tutorial.ipynb
# -rw------- 1 root root  185127 May  8  2024 'meta-llama Meta-Llama-3-70B.ipynb'
# -rw------- 1 root root  146124 Mar 13 10:29  myData.png
# drwx------ 2 root root    4096 Sep 21 04:43  python
# drwx------ 2 root root    4096 Sep 19 10:25 '어프렌티스 프로젝트 (8884002-01)'

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread('./drive/MyDrive/myData.png')
plt.imshow(img)
plt.show()
